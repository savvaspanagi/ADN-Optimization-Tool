# %% [markdown]
# ### In this tutorial the same panadapower test network will be used but also BFM will be included. Overall non-convex BIM, non-convex DistFlow, SOCP DistFlow and non-convex BFM are investigated

# %%
##################----------------- Import Libraries -------------########################

from pyomo.environ import *
from pyomo.opt import SolverFactory
import math
import os
import numpy as np
import pandas as pd
import pandapower as pp
import pandapower.pf as pf
from pandapower import networks
import pandapower.plotting as plot
import pandapower.networks as pn
import matplotlib.pyplot as plt
import random
from scipy import stats
from scipy.stats import t
import sys
current_directory = os.getcwd()

# %%
# For auto reload libraries without the need to restart kernel
############# USE ONLY IN DEVELOPING MODE FOR EASIER MODIFICAITON IN LIBRARIES ##############
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### This is the BFM

# %%
net = pn.simple_four_bus_system()
net.bus['max_vm_pu'] = 1.05
net.bus['min_vm_pu'] = 0.95

# %%
############## Initialize model ######################

sys.path.append('../v8_Main/src')

from Manager import *
manager = Manager(net=net)
manager.addTime(timeframe=48,time_interval=30) ## At objective, timeframe(in hours) , time-interval(in minutes)
manager.anc_Vars.System_Data_DER.loc[0,'Controllable']=True

# %%
#######################------------------- Easy method to get the admittance Matrix ----------------####################33
# Run a power flow calculation

pp.runpp(net)

# Access the Y-bus matrix from the network results
Ybus = net["_ppc"]["internal"]["Ybus"]
# print("Y-bus matrix:\n", Ybus.todense())

# Convert the sparse Y-bus matrix to a dense format and then to a DataFrame
Y_bus_df = pd.DataFrame(Ybus.todense())

# Add row and column labels if needed
Y_bus_df.index = net.bus.index
Y_bus_df.columns = net.bus.index
# print(Y_bus_df)
################### OR ######################

Ybus = build_ybus(net)

### Generate load/DER time scale data
file_path2 = '../Data/profiles/pv_load_profiles/Profiles_for_testing.xlsx'
profiles = pd.read_excel(file_path2)
profiles = pd.concat([profiles]*2, ignore_index=True)

# %%
# Custom Add EVs since in pandapower EVs are not available

manager.anc_Vars.addEV(node=2,P_min_ch=0,P_max_ch=11,Qmin=-3.616 , Qmax=3.616, costh_EV=1, P_control="controllable" , Q_control="controllable" , V2G="False", EV_EC=56, EV_SoC_init=57, EV_SoC_end=100, EV_SoC_min=35, EV_SoC_max=80, EV_cons=17,arrival=[31,31+48],departure=[13,13+48],distance=[1,1])
manager.anc_Vars.addEV(node=3,P_min_ch=0,P_max_ch=11,Qmin=-3.616 , Qmax=3.616, costh_EV=1, P_control="controllable" , Q_control="controllable" , V2G="False", EV_EC=56, EV_SoC_init=30, EV_SoC_end=100, EV_SoC_min=30, EV_SoC_max=80, EV_cons=17,arrival=[36,36+48],departure=[3,3+48],distance=[20,20])

# print(manager.anc_Vars.system_data_ev)
# print(manager.anc_Vars.system_data_ev_char)

# %%
# This code initialize/create all the needed sets in pyomo model.
manager.initialize_sets()  # Initialize sets

print(manager.list_sets())
# manager.show_set("Sbuses")
# manager.show_set("SGrid")
# manager.show_set("SDER_contr")
# manager.show_set("SDER_uncontr")
# manager.show_set("SLoadbuses")
# manager.show_set("Slines")
# manager.show_set("STimes")
# manager.show_set("SEVbuses")
# manager.show_set("SDistance_ind")
# manager.show_set("STransformers")
# Out:
# ['Sbuses', 'SGrid', 'SDER_contr', 'SDER_uncontr', 'SLoadbuses', 'Slines', 'STransformers', 'STimes', 'SEVbuses', 'SDistance_ind', 'Sdownstream', 'Supstream', 'Sdownstream_transformer', 'Supstream_transformer', 'Sreverse_lines', 'Sreverse_transformers']

# %%
############################---------------------- Define Parameters ---------------------############################

# Why defined parameters? if we defined parameters instead of using for example panda dataframe then we can rerun the model without the need to 
# rebuild the constraints during the solving it automatically get the new parameters so the steps for a load modification example is the following
# 1) Define the load profile dataframe, 2) Run variables 3) Run parameters, 4)Build model, 5) Solve optimization, 6)Change load profile , 7) Run parameters ,8) Solve optimization
# MUTABLE=TRUE is the function parameter that allow this

manager.load_profile_param(profiles, "Load_P", "Load_Q") # This create Load_P and Load_Q profile which is equal to PandapowerPower*p.u. [from profiles files]
manager.line_param(Y_bus_df, "resistance_Parm", "reactance_Parm", "admitt_mat_Parm_real", "admitt_mat_Parm_imag")
manager.transformer_param("transformer_resistance_Parm", "transformer_reactance_Parm") # This create resistance and reactance parameters for transformers
manager.alpha_bfm_param("alpha_real_param", "alpha_imag_param", "alpha_transformer_real_param", "alpha_transformer_imag_param") # This create alpha parameters for lines and transformers
############ EV #################
manager.initialize_ev_params("ev_min_ch_param", "ev_max_ch_param", "EVinit_SOC", "EVend_SOC_param", "EV_SoC_min_param", "EV_SoC_max_param", "EV_capacity_param")
manager.initialize_ev_char_params("ev_arrival_time_param", "ev_departure_time_param", "ev_trip_distance_param", "EV_SoC_min_departure_param",  "EV_trip_energy_needs_param", "EV_available_param" )
manager.initialize_ev_min_soc_timeseries("EV_SoC_min_overtime_param")

############ DER #################
manager.der_profile_param(profiles, "unctrl_PV_gen_P", "unctrl_PV_gen_Q", "ctrl_PV_gen_P", "ctrl_PV_gen_Q")

print(manager.list_parameters())
manager.show_parameter("Load_P")
# Out:
# ['Load_P', 'Load_Q', 'resistance_Parm', 'reactance_Parm', 'admitt_mat_Parm_real', 'admitt_mat_Parm_imag', 'transformer_resistance_Parm', 'transformer_reactance_Parm', 'alpha_real_param', 'alpha_imag_param', 'alpha_transformer_real_param', 'alpha_transformer_imag_param', 'ev_min_ch_param', 'ev_max_ch_param', 'EVinit_SOC', 'EVend_SOC_param', 'EV_SoC_min_param', 'EV_SoC_max_param', 'EV_capacity_param', 'ev_arrival_time_param', 'ev_departure_time_param', 'ev_trip_distance_param', 'EV_SoC_min_departure_param', 'EV_trip_energy_needs_param', 'EV_available_param', 'EV_SoC_min_overtime_param', 'unctrl_PV_gen_P', 'ctrl_PV_gen_P', 'unctrl_PV_gen_Q', 'ctrl_PV_gen_Q']
# Variable Load_P:
#   (2, 0): 0.0036752644392
#   (2, 1): 0.00356655123
#   (2, 2): 0.0034975863051
#   (2, 3): 0.0034273171508999996
#   (2, 4): 0.003336370929
#   (2, 5): 0.0031993126830000005
#   (2, 6): 0.0030531054132
#   (2, 7): 0.0029361103880999996
#   (2, 8): 0.0027957841179
#   (2, 9): 0.0026178374244
#   (2, 10): 0.0026060933921999998
#   (2, 11): 0.0024847220564999995
#   (2, 12): 0.0024768300744000002
#   (2, 13): 0.0025240200743999997
#   (2, 14): 0.0025400914929
#   (2, 15): 0.0026397410468999996
#   (2, 16): 0.0010464262673999998
#   (2, 17): 0.0009071987342999998
#   (2, 18): 0.0023779876533
#   (2, 19): 0.0024172075650000006
#   (2, 20): 0.0039061720809000005
#   (2, 21): 0.003945724488899999
#   (2, 22): 0.0024456396597000007
#   (2, 23): 0.0025122650766
#   (2, 24): 0.0026760473883
#   (2, 25): 0.0029396481938999985
#   (2, 26): 0.0030134754579
#   (2, 27): 0.0045105548925
#   (2, 28): 0.003160746951
#   (2, 29): 0.0048252782699999995
#   (2, 30): 0.0035201026448999995
#   (2, 31): 0.0035146695440999996
#   (2, 32): 0.0050392899396
#   (2, 33): 0.0035501720846999995
#   (2, 34): 0.004997208057899999
#   (2, 35): 0.0047285950593
#   (2, 36): 0.004769447943599999
#   (2, 37): 0.0033551184642
#   (2, 38): 0.0029621103095999997
#   (2, 39): 0.0038914259829
#   (2, 40): 0.0028008045306
#   (2, 41): 0.0016104535703999998
#   (2, 42): 0.0032779607529
#   (2, 43): 0.0033494587199999998
#   (2, 44): 0.0033109028012999996
#   (2, 45): 0.0033556955571
#   (2, 46): 0.0034981112951999994
#   (2, 47): 0.0036711359036999997
#   (2, 48): 0.0036752644392
#   (2, 49): 0.00356655123
#   (2, 50): 0.0034975863051
#   (2, 51): 0.0034273171508999996
#   (2, 52): 0.003336370929
#   (2, 53): 0.0031993126830000005
#   (2, 54): 0.0030531054132
#   (2, 55): 0.0029361103880999996
#   (2, 56): 0.0027957841179
#   (2, 57): 0.0026178374244
#   (2, 58): 0.0026060933921999998
#   (2, 59): 0.0024847220564999995
#   (2, 60): 0.0024768300744000002
#   (2, 61): 0.0025240200743999997
#   (2, 62): 0.0025400914929
#   (2, 63): 0.0026397410468999996
#   (2, 64): 0.0010464262673999998
#   (2, 65): 0.0009071987342999998
#   (2, 66): 0.0023779876533
#   (2, 67): 0.0024172075650000006
#   (2, 68): 0.0039061720809000005
#   (2, 69): 0.003945724488899999
#   (2, 70): 0.0024456396597000007
#   (2, 71): 0.0025122650766
#   (2, 72): 0.0026760473883
#   (2, 73): 0.0029396481938999985
#   (2, 74): 0.0030134754579
#   (2, 75): 0.0045105548925
#   (2, 76): 0.003160746951
#   (2, 77): 0.0048252782699999995
#   (2, 78): 0.0035201026448999995
#   (2, 79): 0.0035146695440999996
#   (2, 80): 0.0050392899396
#   (2, 81): 0.0035501720846999995
#   (2, 82): 0.004997208057899999
#   (2, 83): 0.0047285950593
#   (2, 84): 0.004769447943599999
#   (2, 85): 0.0033551184642
#   (2, 86): 0.0029621103095999997
#   (2, 87): 0.0038914259829
#   (2, 88): 0.0028008045306
#   (2, 89): 0.0016104535703999998
#   (2, 90): 0.0032779607529
#   (2, 91): 0.0033494587199999998
#   (2, 92): 0.0033109028012999996
#   (2, 93): 0.0033556955571
#   (2, 94): 0.0034981112951999994
#   (2, 95): 0.0036711359036999997
#   (3, 0): 0.0036752644392
#   (3, 1): 0.00356655123
#   (3, 2): 0.0034975863051
#   (3, 3): 0.0034273171508999996
#   (3, 4): 0.003336370929
#   (3, 5): 0.0031993126830000005
#   (3, 6): 0.0030531054132
#   (3, 7): 0.0029361103880999996
#   (3, 8): 0.0027957841179
#   (3, 9): 0.0026178374244
#   (3, 10): 0.0026060933921999998
#   (3, 11): 0.0024847220564999995
#   (3, 12): 0.0024768300744000002
#   (3, 13): 0.0025240200743999997
#   (3, 14): 0.0025400914929
#   (3, 15): 0.0026397410468999996
#   (3, 16): 0.0010464262673999998
#   (3, 17): 0.0009071987342999998
#   (3, 18): 0.0023779876533
#   (3, 19): 0.0024172075650000006
#   (3, 20): 0.0039061720809000005
#   (3, 21): 0.003945724488899999
#   (3, 22): 0.0024456396597000007
#   (3, 23): 0.0025122650766
#   (3, 24): 0.0026760473883
#   (3, 25): 0.0029396481938999985
#   (3, 26): 0.0030134754579
#   (3, 27): 0.0045105548925
#   (3, 28): 0.003160746951
#   (3, 29): 0.0048252782699999995
#   (3, 30): 0.0035201026448999995
#   (3, 31): 0.0035146695440999996
#   (3, 32): 0.0050392899396
#   (3, 33): 0.0035501720846999995
#   (3, 34): 0.004997208057899999
#   (3, 35): 0.0047285950593
#   (3, 36): 0.004769447943599999
#   (3, 37): 0.0033551184642
#   (3, 38): 0.0029621103095999997
#   (3, 39): 0.0038914259829
#   (3, 40): 0.0028008045306
#   (3, 41): 0.0016104535703999998
#   (3, 42): 0.0032779607529
#   (3, 43): 0.0033494587199999998
#   (3, 44): 0.0033109028012999996
#   (3, 45): 0.0033556955571
#   (3, 46): 0.0034981112951999994
#   (3, 47): 0.0036711359036999997
#   (3, 48): 0.0036752644392
#   (3, 49): 0.00356655123
#   (3, 50): 0.0034975863051
#   (3, 51): 0.0034273171508999996
#   (3, 52): 0.003336370929
#   (3, 53): 0.0031993126830000005
#   (3, 54): 0.0030531054132
#   (3, 55): 0.0029361103880999996
#   (3, 56): 0.0027957841179
#   (3, 57): 0.0026178374244
#   (3, 58): 0.0026060933921999998
#   (3, 59): 0.0024847220564999995
#   (3, 60): 0.0024768300744000002
#   (3, 61): 0.0025240200743999997
#   (3, 62): 0.0025400914929
#   (3, 63): 0.0026397410468999996
#   (3, 64): 0.0010464262673999998
#   (3, 65): 0.0009071987342999998
#   (3, 66): 0.0023779876533
#   (3, 67): 0.0024172075650000006
#   (3, 68): 0.0039061720809000005
#   (3, 69): 0.003945724488899999
#   (3, 70): 0.0024456396597000007
#   (3, 71): 0.0025122650766
#   (3, 72): 0.0026760473883
#   (3, 73): 0.0029396481938999985
#   (3, 74): 0.0030134754579
#   (3, 75): 0.0045105548925
#   (3, 76): 0.003160746951
#   (3, 77): 0.0048252782699999995
#   (3, 78): 0.0035201026448999995
#   (3, 79): 0.0035146695440999996
#   (3, 80): 0.0050392899396
#   (3, 81): 0.0035501720846999995
#   (3, 82): 0.004997208057899999
#   (3, 83): 0.0047285950593
#   (3, 84): 0.004769447943599999
#   (3, 85): 0.0033551184642
#   (3, 86): 0.0029621103095999997
#   (3, 87): 0.0038914259829
#   (3, 88): 0.0028008045306
#   (3, 89): 0.0016104535703999998
#   (3, 90): 0.0032779607529
#   (3, 91): 0.0033494587199999998
#   (3, 92): 0.0033109028012999996
#   (3, 93): 0.0033556955571
#   (3, 94): 0.0034981112951999994
#   (3, 95): 0.0036711359036999997

# %%
############################---------------------- Define Variables ---------------------############################

# ###################### Normal Operation Scenario ########################
manager.initialize_voltage_square_variables(voltage_name_prefix="v")
manager.initialize_power_variable("pgrid", manager.model.SGrid)
manager.initialize_power_variable("qgrid", manager.model.SGrid)
manager.initialize_power_variable("pline", manager.model.Slines)
manager.initialize_power_variable("qline", manager.model.Slines)
manager.initialize_power_variable("pline_reverse", manager.model.Sreverse_lines)
manager.initialize_power_variable("qline_reverse", manager.model.Sreverse_lines)
manager.initialize_power_variable("ptransformer", manager.model.STransformers)
manager.initialize_power_variable("qtransformer", manager.model.STransformers)
manager.initialize_power_variable("ptransformer_reverse", manager.model.Sreverse_transformers)
manager.initialize_power_variable("qtransformer_reverse", manager.model.Sreverse_transformers)
manager.initialize_power_variable("transformer_curr", manager.model.STransformers)
manager.initialize_power_variable("transformer_curr_reverse", manager.model.Sreverse_transformers)
manager.initialize_der_variables("pder_contr", "pder_curtail_contr", "qder_contr")
manager.initialize_line_square_variables(manager.model.Slines, line_curr_name_prefix="Line_curr")
manager.initialize_line_square_variables(manager.model.Sreverse_lines, line_curr_name_prefix="Line_curr_reverse")
manager.initialize_line_variables(line_set=manager.model.Slines,line_losses_name_prefix = "Line_losses")
manager.initialize_line_variables(line_set=manager.model.Sreverse_lines,line_losses_name_prefix = "Line_losses_reverse")

ref_bus=0 # THIS MUST BE ADDED AUTOMATICALLY 
for t in manager.model.STimes:
    manager.model.v[ref_bus, t].fix(1)

###################### EV Variables ########################
manager.initialize_ev_variables("pEVch","qEV", "EVsoc")

print(manager.list_variables())
# Out:
# ['v', 'pgrid', 'qgrid', 'pline', 'qline', 'pline_reverse', 'qline_reverse', 'ptransformer', 'qtransformer', 'ptransformer_reverse', 'qtransformer_reverse', 'transformer_curr', 'transformer_curr_reverse', 'pder_contr', 'pder_curtail_contr', 'qder_contr', 'Line_curr', 'Line_curr_reverse', 'Line_losses', 'Line_losses_reverse', 'pEVch', 'qEV', 'EVsoc']

# %%
####################-------------------- Line Flow constraints -----------------------#######################

manager.add_line_flow_amplitude_losses_constraint(line_set=manager.model.Slines, current_var=manager.model.Line_curr, losses_var=manager.model.Line_losses, line_flow_losses_con_name_prefix="line_losses")
manager.add_line_flow_amplitude_losses_constraint(line_set=manager.model.Sreverse_lines, current_var=manager.model.Line_curr_reverse,losses_var=manager.model.Line_losses_reverse, line_flow_losses_con_name_prefix="reverse_line_losses")


###################-----------------Curtail DER Power Constrain ------------#######################

def Curtail_DER_Power_rule(model, i, time):
    return (model.pder_curtail_contr[i,time] ==  model.pder_curtail_contr[i,  time].ub - model.pder_contr[i,  time])
manager.model.Curtail_DER_cons = Constraint(manager.model.SDER_contr,manager.model.STimes, rule=Curtail_DER_Power_rule)  # Minimum, Maximum power for Gen

####################-------------------- EV Constrain -----------------------#######################

manager.add_ev_soc_constraint("EV_SOC_cons")
# Fix variables for non-charging times
manager.fix_ev_non_charging_times(model_ev_ch=manager.model.pEVch, model_ev_flex_up=None, model_ev_flex_down=None)

# %%
manager.add_active_power_flow_bfm(manager.model.pder_contr, manager.model.pline, manager.model.pline_reverse, manager.model.ptransformer,manager.model.ptransformer_reverse, manager.model.pgrid, manager.model.pEVch, "active_power_flow")
manager.add_reactive_power_flow_bfm(manager.model.qder_contr, manager.model.qline,manager.model.qline_reverse, manager.model.qtransformer,manager.model.qtransformer_reverse, manager.model.qgrid, manager.model.qEV, "reactive_power_flow")
manager.add_voltage_drop_bfm(manager.model.Slines, manager.model.Sreverse_lines,  manager.model.v, manager.model.pline, manager.model.pline_reverse , manager.model.qline, manager.model.qline_reverse, manager.model.Line_curr,manager.model.Line_curr_reverse, manager.model.resistance_Parm , manager.model.reactance_Parm, manager.model.alpha_real_param, manager.model.alpha_imag_param, "voltage_lines_pf","voltage_reverse_lines_pf"  )
manager.add_current_flow_bfm(manager.model.Slines, manager.model.Sreverse_lines, manager.model.pline, manager.model.pline_reverse, manager.model.qline, manager.model.qline_reverse, manager.model.Line_curr, manager.model.Line_curr_reverse, manager.model.v, "current_lines_equal_pf", "current_reverse_lines_equal_pf" )
manager.add_voltage_drop_bfm(manager.model.STransformers, manager.model.Sreverse_transformers,  manager.model.v, manager.model.ptransformer, manager.model.ptransformer_reverse , manager.model.qtransformer, manager.model.qtransformer_reverse, manager.model.transformer_curr,manager.model.transformer_curr_reverse, manager.model.transformer_resistance_Parm , manager.model.transformer_reactance_Parm, manager.model.alpha_transformer_real_param, manager.model.alpha_transformer_imag_param, "voltage_transformers_pf","voltage_reverse_transformers_pf")
manager.add_current_flow_bfm(manager.model.STransformers, manager.model.Sreverse_transformers, manager.model.ptransformer, manager.model.ptransformer_reverse, manager.model.qtransformer, manager.model.qtransformer_reverse, manager.model.transformer_curr, manager.model.transformer_curr_reverse, manager.model.v, "current_transformers_equal_pf", "transformers_reverse_lines_equal_pf" )
manager.add_voltage_link_symmetric_constraint(manager.model.Slines, manager.model.v, manager.model.pline, manager.model.pline_reverse , manager.model.qline, manager.model.qline_reverse, manager.model.resistance_Parm , manager.model.reactance_Parm, manager.model.alpha_real_param, manager.model.alpha_imag_param, "voltage_symmetric_line_real","voltage_symmetric_line_imag")
manager.add_voltage_link_symmetric_constraint(manager.model.STransformers, manager.model.v, manager.model.ptransformer, manager.model.ptransformer_reverse , manager.model.qtransformer, manager.model.qtransformer_reverse, manager.model.transformer_resistance_Parm , manager.model.transformer_reactance_Parm, manager.model.alpha_transformer_real_param, manager.model.alpha_transformer_imag_param, "voltage_symmetric_transformer_real","voltage_symmetric_transformer_imag")

# %%
####################-------------------- Objective -----------------------#######################

def obj_rule(model):

    losses_term = sum(model.Line_losses[sfrom, sto, time]
                      for time in model.STimes 
                      for sfrom, sto in model.Slines)

    curtail_term = 300*sum(model.pder_curtail_contr[der, time]
                       for der in model.SDER_contr
                       for time in model.STimes)
    
    return losses_term + curtail_term

manager.model.obj = Objective(rule=obj_rule, sense=minimize)

# %%
# Define the solver without syntax issues and include line breaks
solver = SolverFactory('ipopt')

solver.options['max_iter'] = 5000  # Increase the maximum number of iterations
solver.options['tol'] = 1e-10       # Set a smaller tolerance for convergence
solver.options['print_level'] = 5  # Higher levels provide more detailed output (0-12)
solver.options['acceptable_tol'] = 1e-2            # early stopping
# solver.options['output_file'] = 'ipopt_log.txt'  # Save IPOPT log to a file

results = solver.solve(manager.model, tee=True)

# After solving, print the results
print("Status: ", results.solver.status)
print("Termination Condition: ", results.solver.termination_condition)

# Check if the solution is feasible
if results.solver.termination_condition == TerminationCondition.optimal:
    
    print("successful")
    # Extract solver timing (wallclock time)
-1.0 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50  6.8947769e-01 2.93e-06 4.35e-02  -3.8 1.70e-03  -0.6 1.00e+00 1.00e+00h  1
#   51  6.8949656e-01 1.19e-06 2.75e-02  -3.8 1.08e-03  -0.2 1.00e+00 1.00e+00h  1
#   52  6.8954623e-01 9.34e-06 7.38e-02  -3.8 3.03e-03  -0.6 1.00e+00 1.00e+00h  1
#   53  6.8954716e-01 4.61e-07 1.62e-02  -3.8 6.65e-04    -  1.00e+00 1.00e+00h  1
#   54  6.8954806e-01 2.09e-07 3.62e-04  -3.8 1.68e-05    -  1.00e+00 1.00e+00h  1
#   55  6.3625438e-01 5.34e-06 1.07e+02  -5.7 2.30e-03    -  7.59e-01 1.00e+00f  1
#   56  6.3249852e-01 7.12e-06 1.83e+02  -5.7 4.28e-03    -  6.90e-01 1.00e+00h  1
#   57  6.2647358e-01 2.64e-05 3.68e+02  -5.7 1.62e-02    -  2.45e-01 1.00e+00h  1
#   58  6.2463731e-01 1.34e-05 3.05e+02  -5.7 1.46e-02    -  4.09e-01 8.67e-01h  1
#   59  6.2325136e-01 4.32e-06 4.78e+02  -5.7 1.07e-02    -  2.87e-01 9.65e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   60  6.2269525e-01 3.61e-06 8.17e+02  -5.7 7.88e-03    -  1.11e-01 1.00e+00f  1
#   61  6.2251735e-01 8.17e-07 1.15e+02  -5.7 3.75e-03    -  3.63e-01 1.00e+00h  1
#   62  6.2244617e-01 9.31e-07 1.21e+00  -5.7 4.01e-03    -  8.74e-01 1.00e+00h  1
#   63  6.2241367e-01 4.56e-07 5.23e-02  -5.7 2.80e-03    -  1.00e+00 1.00e+00h  1
#   64  6.2241144e-01 2.14e-08 1.19e-03  -5.7 7.29e-05  -1.1 1.00e+00 1.00e+00h  1
#   65  6.2240845e-01 2.14e-08 5.81e-04  -5.7 3.53e-05  -0.7 1.00e+00 1.00e+00h  1
#   66  6.2240769e-01 2.14e-08 4.64e-03  -5.7 2.28e-04  -1.2 1.00e+00 1.25e-01h  4
#   67  6.2240570e-01 2.14e-08 9.14e-04  -5.7 6.15e-05  -0.7 1.00e+00 5.00e-01h  2
#
# Number of Iterations....: 67
#
#                                    (scaled)                 (unscaled)
# Objective...............:   2.0746856780440029e-01    6.2240570341320089e-01
# Dual infeasibility......:   9.1410068825879560e-04    2.7423020647763868e-03
# Constraint violation....:   2.1424399580618651e-08    2.1424399580618651e-08
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   1.8585538851438190e-06    5.5756616554314576e-06
# Overall NLP error.......:   9.1410068825879560e-04    2.7423020647763868e-03
#
#
# Number of objective function evaluations             = 116
# Number of objective gradient evaluations             = 69
# Number of equality constraint evaluations            = 116
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 69
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 68
# Total seconds in IPOPT                               = 0.174
#
# EXIT: Solved To Acceptable Level.
# Status:  ok
# Termination Condition:  optimal
# successful
# Solver Time: 0.2041170597076416 seconds

# %%
print("Objective value:", value(manager.model.obj))

manager.results.wrapper_var_results()
print(manager.results.list())
print(manager.results.EVsoc.head())
# Out:
# Objective value: 0.6224057034132008
# ['EVsoc', 'Line_curr', 'Line_curr_reverse', 'Line_losses', 'Line_losses_reverse', 'pEVch', 'pder_contr', 'pder_curtail_contr', 'pgrid', 'pline', 'pline_reverse', 'ptransformer', 'ptransformer_reverse', 'qEV', 'qder_contr', 'qgrid', 'qline', 'qline_reverse', 'qtransformer', 'qtransformer_reverse', 'transformer_curr', 'transformer_curr_reverse', 'v']
#           2         3
# 0  0.031963  0.018047
# 1  0.032006  0.019283
# 2  0.032050  0.020530
# 3  0.032108  0.020530
# 4  0.032168  0.020530

# %%
manager.plot_fun.result_df_plot(manager.results.pEVch*manager.anc_Vars.S_Base*1000,"EV Charge Power", "time [hh:mm]" ,"Active Power [kW]")
manager.plot_fun.result_df_plot(manager.results.EVsoc*manager.anc_Vars.S_Base*1000,"EV SoC", "Time (hh-mm)" ,"SoC (kWh)",label="Yes")
manager.plot_fun.result_df_plot(manager.results.Line_losses*manager.anc_Vars.I_base*1000,"Line Losses", "Time (hh-mm)" ,"Losses (Joule)",label="Yes")
manager.plot_fun.result_df_plot(manager.results.qEV*manager.anc_Vars.S_Base*1000,"EV reactive power", "Time (hh-mm)" ,"Q (kVAr)",label="Yes")
manager.plot_fun.result_df_plot(manager.results.pder_contr*manager.anc_Vars.S_Base*1000,"Pder_contrl", "Time (hh-mm)" ,"P (kW)",label="Yes")
manager.plot_fun.result_df_plot(manager.results.pder_curtail_contr*manager.anc_Vars.S_Base*1000,"Pder_contrl_curtail", "Time (hh-mm)" ,"P (kW)",label="Yes")
manager.plot_fun.result_df_plot(manager.results.qder_contr*manager.anc_Vars.S_Base*1000,"Qder_contrl_reactive_power", "Time (hh-mm)" ,"Q (kVAr)",label="Yes")
manager.plot_fun.result_df_plot(np.sqrt(manager.results.v),"Voltage", "Time (hh-mm)" ,"Voltage (p.u.)", label="Yes")

# %% [markdown]
# ### This is the BIM formulation and run

# %%
net = pn.simple_four_bus_system()
net.bus['max_vm_pu'] = 1.05
net.bus['min_vm_pu'] = 0.95

# %%
############## Initialize model ######################

sys.path.append('../v8_Main/src')

from Manager import *
manager = Manager(net=net)
manager.addTime(timeframe=48,time_interval=30) ## At objective, timeframe(in hours) , time-interval(in minutes)
manager.anc_Vars.System_Data_DER.loc[0,'Controllable']=True

# %%
#######################------------------- Easy method to get the admittance Matrix ----------------####################33
# Run a power flow calculation

pp.runpp(net)

# Access the Y-bus matrix from the network results
Ybus = net["_ppc"]["internal"]["Ybus"]
# print("Y-bus matrix:\n", Ybus.todense())

# Convert the sparse Y-bus matrix to a dense format and then to a DataFrame
Y_bus_df = pd.DataFrame(Ybus.todense())

# Add row and column labels if needed
Y_bus_df.index = net.bus.index
Y_bus_df.columns = net.bus.index
# print(Y_bus_df)
################### OR ######################

Ybus = build_ybus(net)

### Generate load/DER time scale data
file_path2 = '../Data/profiles/pv_load_profiles/Profiles_for_testing.xlsx'
profiles = pd.read_excel(file_path2)
profiles = pd.concat([profiles]*2, ignore_index=True)

# %%
# Custom Add EVs since in pandapower EVs are not available

manager.anc_Vars.addEV(node=2,P_min_ch=0,P_max_ch=11,Qmin=-3.616 , Qmax=3.616, costh_EV=1, P_control="controllable" , Q_control="controllable" , V2G="False", EV_EC=56, EV_SoC_init=57, EV_SoC_end=100, EV_SoC_min=35, EV_SoC_max=80, EV_cons=17,arrival=[31,31+48],departure=[13,13+48],distance=[1,1])
manager.anc_Vars.addEV(node=3,P_min_ch=0,P_max_ch=11,Qmin=-3.616 , Qmax=3.616, costh_EV=1, P_control="controllable" , Q_control="controllable" , V2G="False", EV_EC=56, EV_SoC_init=30, EV_SoC_end=100, EV_SoC_min=30, EV_SoC_max=80, EV_cons=17,arrival=[36,36+48],departure=[3,3+48],distance=[20,20])
# print(manager.anc_Vars.system_data_ev)
# print(manager.anc_Vars.system_data_ev_char)

# %%
# This code initialize/create all the needed sets in pyomo model.
manager.initialize_sets()  # Initialize sets

print(manager.list_sets())
# manager.show_set("Sbuses")
# manager.show_set("SGrid")
# manager.show_set("SDER_contr")
# manager.show_set("SDER_uncontr")
# manager.show_set("SLoadbuses")
# manager.show_set("Slines")
# manager.show_set("STimes")
# manager.show_set("SEVbuses")
# manager.show_set("SDistance_ind")
# manager.show_set("STransformers")
# Out:
# ['Sbuses', 'SGrid', 'SDER_contr', 'SDER_uncontr', 'SLoadbuses', 'Slines', 'STransformers', 'STimes', 'SEVbuses', 'SDistance_ind', 'Sdownstream', 'Supstream', 'Sdownstream_transformer', 'Supstream_transformer', 'Sreverse_lines', 'Sreverse_transformers']

# %%
############################---------------------- Define Parameters ---------------------############################

# Why defined parameters? if we defined parameters instead of using for example panda dataframe then we can rerun the model without the need to 
# rebuild the constraints during the solving it automatically get the new parameters so the steps for a load modification example is the following
# 1) Define the load profile dataframe, 2) Run variables 3) Run parameters, 4)Build model, 5) Solve optimization, 6)Change load profile , 7) Run parameters ,8) Solve optimization
# MUTABLE=TRUE is the function parameter that allow this

manager.load_profile_param(profiles, "Load_P", "Load_Q") # This create Load_P and Load_Q profile which is equal to PandapowerPower*p.u. [from profiles files]
manager.line_param(Y_bus_df, "resistance_Parm", "reactance_Parm", "admitt_mat_Parm_real", "admitt_mat_Parm_imag")
manager.transformer_param("transformer_resistance_Parm", "transformer_reactance_Parm") # This create resistance and reactance parameters for transformers
############ EV #################
manager.initialize_ev_params("ev_min_ch_param", "ev_max_ch_param", "EVinit_SOC", "EVend_SOC_param", "EV_SoC_min_param", "EV_SoC_max_param", "EV_capacity_param")
manager.initialize_ev_char_params("ev_arrival_time_param", "ev_departure_time_param", "ev_trip_distance_param", "EV_SoC_min_departure_param",  "EV_trip_energy_needs_param", "EV_available_param" )
manager.initialize_ev_min_soc_timeseries("EV_SoC_min_overtime_param")

############ DER #################
manager.der_profile_param(profiles, "unctrl_PV_gen_P", "unctrl_PV_gen_Q", "ctrl_PV_gen_P", "ctrl_PV_gen_Q")

print(manager.list_parameters())
manager.show_parameter("Load_P")
# Out:
# ['Load_P', 'Load_Q', 'resistance_Parm', 'reactance_Parm', 'admitt_mat_Parm_real', 'admitt_mat_Parm_imag', 'transformer_resistance_Parm', 'transformer_reactance_Parm', 'ev_min_ch_param', 'ev_max_ch_param', 'EVinit_SOC', 'EVend_SOC_param', 'EV_SoC_min_param', 'EV_SoC_max_param', 'EV_capacity_param', 'ev_arrival_time_param', 'ev_departure_time_param', 'ev_trip_distance_param', 'EV_SoC_min_departure_param', 'EV_trip_energy_needs_param', 'EV_available_param', 'EV_SoC_min_overtime_param', 'unctrl_PV_gen_P', 'ctrl_PV_gen_P', 'unctrl_PV_gen_Q', 'ctrl_PV_gen_Q']
# Variable Load_P:
#   (2, 0): 0.0036752644392
#   (2, 1): 0.00356655123
#   (2, 2): 0.0034975863051
#   (2, 3): 0.0034273171508999996
#   (2, 4): 0.003336370929
#   (2, 5): 0.0031993126830000005
#   (2, 6): 0.0030531054132
#   (2, 7): 0.0029361103880999996
#   (2, 8): 0.0027957841179
#   (2, 9): 0.0026178374244
#   (2, 10): 0.0026060933921999998
#   (2, 11): 0.0024847220564999995
#   (2, 12): 0.0024768300744000002
#   (2, 13): 0.0025240200743999997
#   (2, 14): 0.0025400914929
#   (2, 15): 0.0026397410468999996
#   (2, 16): 0.0010464262673999998
#   (2, 17): 0.0009071987342999998
#   (2, 18): 0.0023779876533
#   (2, 19): 0.0024172075650000006
#   (2, 20): 0.0039061720809000005
#   (2, 21): 0.003945724488899999
#   (2, 22): 0.0024456396597000007
#   (2, 23): 0.0025122650766
#   (2, 24): 0.0026760473883
#   (2, 25): 0.0029396481938999985
#   (2, 26): 0.0030134754579
#   (2, 27): 0.0045105548925
#   (2, 28): 0.003160746951
#   (2, 29): 0.0048252782699999995
#   (2, 30): 0.0035201026448999995
#   (2, 31): 0.0035146695440999996
#   (2, 32): 0.0050392899396
#   (2, 33): 0.0035501720846999995
#   (2, 34): 0.004997208057899999
#   (2, 35): 0.0047285950593
#   (2, 36): 0.004769447943599999
#   (2, 37): 0.0033551184642
#   (2, 38): 0.0029621103095999997
#   (2, 39): 0.0038914259829
#   (2, 40): 0.0028008045306
#   (2, 41): 0.0016104535703999998
#   (2, 42): 0.0032779607529
#   (2, 43): 0.0033494587199999998
#   (2, 44): 0.0033109028012999996
#   (2, 45): 0.0033556955571
#   (2, 46): 0.0034981112951999994
#   (2, 47): 0.0036711359036999997
#   (2, 48): 0.0036752644392
#   (2, 49): 0.00356655123
#   (2, 50): 0.0034975863051
#   (2, 51): 0.0034273171508999996
#   (2, 52): 0.003336370929
#   (2, 53): 0.0031993126830000005
#   (2, 54): 0.0030531054132
#   (2, 55): 0.0029361103880999996
#   (2, 56): 0.0027957841179
#   (2, 57): 0.0026178374244
#   (2, 58): 0.0026060933921999998
#   (2, 59): 0.0024847220564999995
#   (2, 60): 0.0024768300744000002
#   (2, 61): 0.0025240200743999997
#   (2, 62): 0.0025400914929
#   (2, 63): 0.0026397410468999996
#   (2, 64): 0.0010464262673999998
#   (2, 65): 0.0009071987342999998
#   (2, 66): 0.0023779876533
#   (2, 67): 0.0024172075650000006
#   (2, 68): 0.0039061720809000005
#   (2, 69): 0.003945724488899999
#   (2, 70): 0.0024456396597000007
#   (2, 71): 0.0025122650766
#   (2, 72): 0.0026760473883
#   (2, 73): 0.0029396481938999985
#   (2, 74): 0.0030134754579
#   (2, 75): 0.0045105548925
#   (2, 76): 0.003160746951
#   (2, 77): 0.0048252782699999995
#   (2, 78): 0.0035201026448999995
#   (2, 79): 0.0035146695440999996
#   (2, 80): 0.0050392899396
#   (2, 81): 0.0035501720846999995
#   (2, 82): 0.004997208057899999
#   (2, 83): 0.0047285950593
#   (2, 84): 0.004769447943599999
#   (2, 85): 0.0033551184642
#   (2, 86): 0.0029621103095999997
#   (2, 87): 0.0038914259829
#   (2, 88): 0.0028008045306
#   (2, 89): 0.0016104535703999998
#   (2, 90): 0.0032779607529
#   (2, 91): 0.0033494587199999998
#   (2, 92): 0.0033109028012999996
#   (2, 93): 0.0033556955571
#   (2, 94): 0.0034981112951999994
#   (2, 95): 0.0036711359036999997
#   (3, 0): 0.0036752644392
#   (3, 1): 0.00356655123
#   (3, 2): 0.0034975863051
#   (3, 3): 0.0034273171508999996
#   (3, 4): 0.003336370929
#   (3, 5): 0.0031993126830000005
#   (3, 6): 0.0030531054132
#   (3, 7): 0.0029361103880999996
#   (3, 8): 0.0027957841179
#   (3, 9): 0.0026178374244
#   (3, 10): 0.0026060933921999998
#   (3, 11): 0.0024847220564999995
#   (3, 12): 0.0024768300744000002
#   (3, 13): 0.0025240200743999997
#   (3, 14): 0.0025400914929
#   (3, 15): 0.0026397410468999996
#   (3, 16): 0.0010464262673999998
#   (3, 17): 0.0009071987342999998
#   (3, 18): 0.0023779876533
#   (3, 19): 0.0024172075650000006
#   (3, 20): 0.0039061720809000005
#   (3, 21): 0.003945724488899999
#   (3, 22): 0.0024456396597000007
#   (3, 23): 0.0025122650766
#   (3, 24): 0.0026760473883
#   (3, 25): 0.0029396481938999985
#   (3, 26): 0.0030134754579
#   (3, 27): 0.0045105548925
#   (3, 28): 0.003160746951
#   (3, 29): 0.0048252782699999995
#   (3, 30): 0.0035201026448999995
#   (3, 31): 0.0035146695440999996
#   (3, 32): 0.0050392899396
#   (3, 33): 0.0035501720846999995
#   (3, 34): 0.004997208057899999
#   (3, 35): 0.0047285950593
#   (3, 36): 0.004769447943599999
#   (3, 37): 0.0033551184642
#   (3, 38): 0.0029621103095999997
#   (3, 39): 0.0038914259829
#   (3, 40): 0.0028008045306
#   (3, 41): 0.0016104535703999998
#   (3, 42): 0.0032779607529
#   (3, 43): 0.0033494587199999998
#   (3, 44): 0.0033109028012999996
#   (3, 45): 0.0033556955571
#   (3, 46): 0.0034981112951999994
#   (3, 47): 0.0036711359036999997
#   (3, 48): 0.0036752644392
#   (3, 49): 0.00356655123
#   (3, 50): 0.0034975863051
#   (3, 51): 0.0034273171508999996
#   (3, 52): 0.003336370929
#   (3, 53): 0.0031993126830000005
#   (3, 54): 0.0030531054132
#   (3, 55): 0.0029361103880999996
#   (3, 56): 0.0027957841179
#   (3, 57): 0.0026178374244
#   (3, 58): 0.0026060933921999998
#   (3, 59): 0.0024847220564999995
#   (3, 60): 0.0024768300744000002
#   (3, 61): 0.0025240200743999997
#   (3, 62): 0.0025400914929
#   (3, 63): 0.0026397410468999996
#   (3, 64): 0.0010464262673999998
#   (3, 65): 0.0009071987342999998
#   (3, 66): 0.0023779876533
#   (3, 67): 0.0024172075650000006
#   (3, 68): 0.0039061720809000005
#   (3, 69): 0.003945724488899999
#   (3, 70): 0.0024456396597000007
#   (3, 71): 0.0025122650766
#   (3, 72): 0.0026760473883
#   (3, 73): 0.0029396481938999985
#   (3, 74): 0.0030134754579
#   (3, 75): 0.0045105548925
#   (3, 76): 0.003160746951
#   (3, 77): 0.0048252782699999995
#   (3, 78): 0.0035201026448999995
#   (3, 79): 0.0035146695440999996
#   (3, 80): 0.0050392899396
#   (3, 81): 0.0035501720846999995
#   (3, 82): 0.004997208057899999
#   (3, 83): 0.0047285950593
#   (3, 84): 0.004769447943599999
#   (3, 85): 0.0033551184642
#   (3, 86): 0.0029621103095999997
#   (3, 87): 0.0038914259829
#   (3, 88): 0.0028008045306
#   (3, 89): 0.0016104535703999998
#   (3, 90): 0.0032779607529
#   (3, 91): 0.0033494587199999998
#   (3, 92): 0.0033109028012999996
#   (3, 93): 0.0033556955571
#   (3, 94): 0.0034981112951999994
#   (3, 95): 0.0036711359036999997

# %%
############################---------------------- Define Variables ---------------------############################

# ###################### Normal Operation Scenario ########################
manager.initialize_voltage_variables("v", "pa")
manager.initialize_power_variable("pgrid", manager.model.SGrid)
manager.initialize_power_variable("qgrid", manager.model.SGrid)
manager.initialize_der_variables("pder_contr", "pder_curtail_contr", "qder_contr")
manager.initialize_line_variables(manager.model.Slines, "Line_curr", "Line_rea_curr", "Line_act_curr", "Line_losses")

ref_bus=0 # THIS MUST BE ADDED AUTOMATICALLY 
for t in manager.model.STimes:
    manager.model.v[ref_bus, t].fix(1)
    manager.model.pa[ref_bus, t].fix(0)

###################### EV Variables ########################

manager.initialize_ev_variables("pEVch","qEV", "EVsoc")

print(manager.list_variables())
# Out:
# ['v', 'pa', 'pgrid', 'qgrid', 'pder_contr', 'pder_curtail_contr', 'qder_contr', 'Line_curr', 'Line_rea_curr', 'Line_act_curr', 'Line_losses', 'pEVch', 'qEV', 'EVsoc']

# %%
########### Line Flow constraints ########################

manager.add_real_line_flow_constraint("real_line_flow", manager.model.Line_act_curr, manager.model.v, manager.model.pa)
manager.add_reactive_line_flow_constraint("reactive_line_flow", manager.model.Line_rea_curr, manager.model.v, manager.model.pa)
manager.add_line_flow_constraint("line_flow", manager.model.Line_curr, manager.model.Line_act_curr, manager.model.Line_rea_curr)
manager.add_line_flow_losses_constraint(manager.model.Line_curr, "line_losses")

###################-----------------Curtail DER Power Constrain ------------#######################

def Curtail_DER_Power_rule(model, i, time):
    return (model.pder_curtail_contr[i,time] ==  model.pder_curtail_contr[i,  time].ub - model.pder_contr[i,  time])
manager.model.Curtail_DER_cons = Constraint(manager.model.SDER_contr,manager.model.STimes, rule=Curtail_DER_Power_rule)  # Minimum, Maximum power for Gen

####################-------------------- EV Constrain -----------------------#######################
manager.add_ev_soc_constraint("EV_SOC_cons")
# Fix variables for non-charging times
manager.fix_ev_non_charging_times(model_ev_ch=manager.model.pEVch, model_ev_flex_up=None, model_ev_flex_down=None)

####################-------------------- Power Flow Constrain -----------------------#######################

manager.add_active_power_flow_constraint(manager.model.pder_contr, manager.model.pgrid, manager.model.pEVch, manager.model.v, manager.model.pa, "active_power_flow")
manager.add_reactive_power_flow_constraint(manager.model.qder_contr, manager.model.qgrid, manager.model.qEV, manager.model.v, manager.model.pa, "reactive_power_flow")

# %%
####################-------------------- Objective -----------------------#######################

def obj_rule(model):

    losses_term = sum(model.Line_losses[sfrom, sto, time]
                      for time in model.STimes 
                      for sfrom, sto in model.Slines)

    curtail_term = 300*sum(model.pder_curtail_contr[der, time]
                       for der in model.SDER_contr
                       for time in model.STimes)
    
    return losses_term + curtail_term

manager.model.obj = Objective(rule=obj_rule, sense=minimize)

# %%
# Define the solver without syntax issues and include line breaks
solver = SolverFactory('ipopt')

solver.options['max_iter'] = 5000  # Increase the maximum number of iterations
solver.options['tol'] = 1e-10       # Set a smaller tolerance for convergence
solver.options['print_level'] = 5  # Higher levels provide more detailed output (0-12)
# solver.options['acceptable_tol'] = 1e-4            # early stopping
# solver.options['output_file'] = 'ipopt_log.txt'  # Save IPOPT log to a file

results = solver.solve(manager.model, tee=True)

# After solving, print the results
print("Status: ", results.solver.status)
print("Termination Condition: ", results.solver.termination_condition)

# Check if the solution is feasible
if results.solver.termination_condition == TerminationCondition.optimal:
    
    print("successful")
    # Extract solver timing (wallclock time)
    solver_time = results.solver.time  # Total solving time in seconds
    print(f"Solver Time: {solver_time} seconds")

else:
    print("Infeasible solution.")
# Out:
# Ipopt 3.14.17: max_iter=5000
# tol=1e-10
# print_level=5
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.17, running with linear solver MUMPS 5.6.2.
#
# Number of nonzeros in equality constraint Jacobian...:     7180
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     2208
#
# Total number of variables............................:     2196
#                      variables with only lower bounds:      192
#                 variables with lower and upper bounds:     1428
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     1824
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  3.2804431e+00 1.21e+01 3.62e+01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  3.2868173e+00 1.21e+01 3.51e+01  -1.0 8.07e+00   2.0 1.12e-02 2.78e-06f  1
#    2  8.6651901e+00 1.18e+01 3.49e+01  -1.0 8.10e+00   1.5 5.71e-03 2.23e-02f  1
#    3  3.2177004e+00 1.17e+01 4.46e+01  -1.0 7.91e+00   2.9 1.16e-02 4.22e-03h  1
#    4  3.5546853e+00 1.16e+01 6.39e+01  -1.0 7.86e+00   2.4 2.83e-02 1.31e-02h  1
#    5  3.5978932e+00 1.16e+01 6.43e+01  -1.0 8.17e+00    -  3.25e-03 1.68e-03h  1
#    6  3.1248805e+00 1.16e+01 1.67e+02  -1.0 7.73e+00   3.7 4.75e-03 1.22e-03h  1
#    7  2.5901399e+00 1.15e+01 2.57e+02  -1.0 7.71e+00   4.1 1.20e-03 1.49e-03h  1
#    8  2.2891177e+00 1.15e+01 4.62e+02  -1.0 7.70e+00   4.6 1.34e-03 7.43e-04h  1
#    9  2.1388619e+00 1.15e+01 1.81e+03  -1.0 7.69e+00   4.1 8.45e-03 3.31e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  2.
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 123
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 116
# Total seconds in IPOPT                               = 0.181
#
# EXIT: Optimal Solution Found.
# Status:  ok
# Termination Condition:  optimal
# successful
# Solver Time: 0.20216822624206543 seconds

# %%
print("Objective value:", value(manager.model.obj))

manager.results.wrapper_var_results()
print(manager.results.list())
print(manager.results.EVsoc.head())
# Out:
# Objective value: 0.6159592994478028
# ['EVsoc', 'Line_act_curr', 'Line_curr', 'Line_losses', 'Line_rea_curr', 'pEVch', 'pa', 'pder_contr', 'pder_curtail_contr', 'pgrid', 'qEV', 'qder_contr', 'qgrid', 'v']
#          2         3
# 0  0.03192  0.017862
# 1  0.03192  0.019005
# 2  0.03192  0.020200
# 3  0.03192  0.020200
# 4  0.03192  0.020200

# %%
manager.plot_fun.result_df_plot(manager.results.pEVch*manager.anc_Vars.S_Base*1000,"EV Charge Power", "time [hh:mm]" ,"Active Power [kW]")
manager.plot_fun.result_df_plot(manager.results.EVsoc*manager.anc_Vars.S_Base*1000,"EV SoC", "Time (hh-mm)" ,"SoC (kWh)",label="Yes")
manager.plot_fun.result_df_plot(manager.results.Line_losses*manager.anc_Vars.I_base*1000,"Line Losses", "Time (hh-mm)" ,"Losses (Joule)",label="Yes")
manager.plot_fun.result_df_plot(manager.results.qEV*manager.anc_Vars.S_Base*1000,"EV reactive power", "Time (hh-mm)" ,"Q (kVAr)",label="Yes")
manager.plot_fun.result_df_plot(manager.results.pder_contr*manager.anc_Vars.S_Base*1000,"Pder_contrl", "Time (hh-mm)" ,"P (kW)",label="Yes")
manager.plot_fun.result_df_plot(manager.results.pder_curtail_contr*manager.anc_Vars.S_Base*1000,"Pder_contrl_curtail", "Time (hh-mm)" ,"P (kW)",label="Yes")
manager.plot_fun.result_df_plot(manager.results.qder_contr*manager.anc_Vars.S_Base*1000,"Qder_contrl_reactive_power", "Time (hh-mm)" ,"Q (kVAr)",label="Yes")
manager.plot_fun.result_df_plot(manager.results.v,"Voltage", "Time (hh-mm)" ,"Voltage (p.u.)", label="Yes")
manager.plot_fun.result_df_plot(manager.results.pa,"Voltage", "Time (hh-mm)" ,"Phase Angle (rad)")

# %% [markdown]
# ### Here the BFM [DISTFLOW] is been formulated and executed again with IPOPT since it was not convex

# %%
net = pn.simple_four_bus_system()
net.bus['max_vm_pu'] = 1.05
net.bus['min_vm_pu'] = 0.95

# %%
sys.path.append('../v8_Main/src')

from Manager import *
manager = Manager(net=net)
manager.addTime(timeframe=48,time_interval=30) ## At objective, timeframe(in hours) , time-interval(in minutes)
manager.anc_Vars.System_Data_DER.loc[0,'Controllable']=True

# %%
#######################------------------- Easy method to get the admittance Matrix ----------------####################33
# Run a power flow calculation

pp.runpp(net)

# Access the Y-bus matrix from the network results
Ybus = net["_ppc"]["internal"]["Ybus"]
# print("Y-bus matrix:\n", Ybus.todense())

# Convert the sparse Y-bus matrix to a dense format and then to a DataFrame
Y_bus_df = pd.DataFrame(Ybus.todense())

# Add row and column labels if needed
Y_bus_df.index = net.bus.index
Y_bus_df.columns = net.bus.index
# print(Y_bus_df)
################### OR ######################

Ybus = build_ybus(net)

### Generate load/DER time scale data
file_path2 = '../Data/profiles/pv_load_profiles/Profiles_for_testing.xlsx'
profiles = pd.read_excel(file_path2)
profiles = pd.concat([profiles]*2, ignore_index=True)

# %%
# Custom Add EVs since in pandapower EVs are not available


manager.anc_Vars.addEV(node=2,P_min_ch=0,P_max_ch=11,Qmin=-3.616 , Qmax=3.616, costh_EV=1, P_control="controllable" , Q_control="controllable" , V2G="False", EV_EC=56, EV_SoC_init=57, EV_SoC_end=100, EV_SoC_min=35, EV_SoC_max=80, EV_cons=17,arrival=[31,31+48],departure=[13,13+48],distance=[1,1])
manager.anc_Vars.addEV(node=3,P_min_ch=0,P_max_ch=11,Qmin=-3.616 , Qmax=3.616, costh_EV=1, P_control="controllable" , Q_control="controllable" , V2G="False", EV_EC=56, EV_SoC_init=30, EV_SoC_end=100, EV_SoC_min=30, EV_SoC_max=80, EV_cons=17,arrival=[36,36+48],departure=[3,3+48],distance=[20,20])

# print(manager.anc_Vars.system_data_ev)
# print(manager.anc_Vars.system_data_ev_char)

# %%
# This code initialize/create all the needed sets in pyomo model.
manager.initialize_sets()  # Initialize sets

print(manager.list_sets())
# manager.show_set("Sbuses")
# manager.show_set("SGrid")
# manager.show_set("SDER_contr")
# manager.show_set("SDER_uncontr")
# manager.show_set("SLoadbuses")
# manager.show_set("Slines")
# manager.show_set("STimes")
# manager.show_set("SEVbuses")
# manager.show_set("SDistance_ind")
# Out:
# ['Sbuses', 'SGrid', 'SDER_contr', 'SDER_uncontr', 'SLoadbuses', 'Slines', 'STransformers', 'STimes', 'SEVbuses', 'SDistance_ind', 'Sdownstream', 'Supstream', 'Sdownstream_transformer', 'Supstream_transformer', 'Sreverse_lines', 'Sreverse_transformers']

# %%
############################---------------------- Define Parameters ---------------------############################

# Why defined parameters? if we defined parameters instead of using for example panda dataframe then we can rerun the model without the need to 
# rebuild the constraints during the solving it automatically get the new parameters so the steps for a load modification example is the following
# 1) Define the load profile dataframe, 2) Run variables 3) Run parameters, 4)Build model, 5) Solve optimization, 6)Change load profile , 7) Run parameters ,8) Solve optimization
# MUTABLE=TRUE is the function parameter that allow this

manager.load_profile_param(profiles, "Load_P", "Load_Q") # This create Load_P and Load_Q profile which is equal to PandapowerPower*p.u. [from profiles files]
manager.line_param(Y_bus_df, "resistance_Parm", "reactance_Parm", "admitt_mat_Parm_real", "admitt_mat_Parm_imag")
manager.transformer_param("transformer_resistance_Parm", "transformer_reactance_Parm") # This create resistance and reactance parameters for transformers

############ EV #################
manager.initialize_ev_params("ev_min_ch_param", "ev_max_ch_param", "EVinit_SOC", "EVend_SOC_param", "EV_SoC_min_param", "EV_SoC_max_param", "EV_capacity_param")
manager.initialize_ev_char_params("ev_arrival_time_param", "ev_departure_time_param", "ev_trip_distance_param", "EV_SoC_min_departure_param",  "EV_trip_energy_needs_param", "EV_available_param" )
manager.initialize_ev_min_soc_timeseries("EV_SoC_min_overtime_param")

############ DER #################
manager.der_profile_param(profiles, "unctrl_PV_gen_P", "unctrl_PV_gen_Q", "ctrl_PV_gen_P", "ctrl_PV_gen_Q")

print(manager.list_parameters())
manager.show_parameter("Load_P")
# Out:
# ['Load_P', 'Load_Q', 'resistance_Parm', 'reactance_Parm', 'admitt_mat_Parm_real', 'admitt_mat_Parm_imag', 'transformer_resistance_Parm', 'transformer_reactance_Parm', 'ev_min_ch_param', 'ev_max_ch_param', 'EVinit_SOC', 'EVend_SOC_param', 'EV_SoC_min_param', 'EV_SoC_max_param', 'EV_capacity_param', 'ev_arrival_time_param', 'ev_departure_time_param', 'ev_trip_distance_param', 'EV_SoC_min_departure_param', 'EV_trip_energy_needs_param', 'EV_available_param', 'EV_SoC_min_overtime_param', 'unctrl_PV_gen_P', 'ctrl_PV_gen_P', 'unctrl_PV_gen_Q', 'ctrl_PV_gen_Q']
# Variable Load_P:
#   (2, 0): 0.0036752644392
#   (2, 1): 0.00356655123
#   (2, 2): 0.0034975863051
#   (2, 3): 0.0034273171508999996
#   (2, 4): 0.003336370929
#   (2, 5): 0.0031993126830000005
#   (2, 6): 0.0030531054132
#   (2, 7): 0.0029361103880999996
#   (2, 8): 0.0027957841179
#   (2, 9): 0.0026178374244
#   (2, 10): 0.0026060933921999998
#   (2, 11): 0.0024847220564999995
#   (2, 12): 0.0024768300744000002
#   (2, 13): 0.0025240200743999997
#   (2, 14): 0.0025400914929
#   (2, 15): 0.0026397410468999996
#   (2, 16): 0.0010464262673999998
#   (2, 17): 0.0009071987342999998
#   (2, 18): 0.0023779876533
#   (2, 19): 0.0024172075650000006
#   (2, 20): 0.0039061720809000005
#   (2, 21): 0.003945724488899999
#   (2, 22): 0.0024456396597000007
#   (2, 23): 0.0025122650766
#   (2, 24): 0.0026760473883
#   (2, 25): 0.0029396481938999985
#   (2, 26): 0.0030134754579
#   (2, 27): 0.0045105548925
#   (2, 28): 0.003160746951
#   (2, 29): 0.0048252782699999995
#   (2, 30): 0.0035201026448999995
#   (2, 31): 0.0035146695440999996
#   (2, 32): 0.0050392899396
#   (2, 33): 0.0035501720846999995
#   (2, 34): 0.004997208057899999
#   (2, 35): 0.0047285950593
#   (2, 36): 0.004769447943599999
#   (2, 37): 0.0033551184642
#   (2, 38): 0.0029621103095999997
#   (2, 39): 0.0038914259829
#   (2, 40): 0.0028008045306
#   (2, 41): 0.0016104535703999998
#   (2, 42): 0.0032779607529
#   (2, 43): 0.0033494587199999998
#   (2, 44): 0.0033109028012999996
#   (2, 45): 0.0033556955571
#   (2, 46): 0.0034981112951999994
#   (2, 47): 0.0036711359036999997
#   (2, 48): 0.0036752644392
#   (2, 49): 0.00356655123
#   (2, 50): 0.0034975863051
#   (2, 51): 0.0034273171508999996
#   (2, 52): 0.003336370929
#   (2, 53): 0.0031993126830000005
#   (2, 54): 0.0030531054132
#   (2, 55): 0.0029361103880999996
#   (2, 56): 0.0027957841179
#   (2, 57): 0.0026178374244
#   (2, 58): 0.0026060933921999998
#   (2, 59): 0.0024847220564999995
#   (2, 60): 0.0024768300744000002
#   (2, 61): 0.0025240200743999997
#   (2, 62): 0.0025400914929
#   (2, 63): 0.0026397410468999996
#   (2, 64): 0.0010464262673999998
#   (2, 65): 0.0009071987342999998
#   (2, 66): 0.0023779876533
#   (2, 67): 0.0024172075650000006
#   (2, 68): 0.0039061720809000005
#   (2, 69): 0.003945724488899999
#   (2, 70): 0.0024456396597000007
#   (2, 71): 0.0025122650766
#   (2, 72): 0.0026760473883
#   (2, 73): 0.0029396481938999985
#   (2, 74): 0.0030134754579
#   (2, 75): 0.0045105548925
#   (2, 76): 0.003160746951
#   (2, 77): 0.0048252782699999995
#   (2, 78): 0.0035201026448999995
#   (2, 79): 0.0035146695440999996
#   (2, 80): 0.0050392899396
#   (2, 81): 0.0035501720846999995
#   (2, 82): 0.004997208057899999
#   (2, 83): 0.0047285950593
#   (2, 84): 0.004769447943599999
#   (2, 85): 0.0033551184642
#   (2, 86): 0.0029621103095999997
#   (2, 87): 0.0038914259829
#   (2, 88): 0.0028008045306
#   (2, 89): 0.0016104535703999998
#   (2, 90): 0.0032779607529
#   (2, 91): 0.0033494587199999998
#   (2, 92): 0.0033109028012999996
#   (2, 93): 0.0033556955571
#   (2, 94): 0.0034981112951999994
#   (2, 95): 0.0036711359036999997
#   (3, 0): 0.0036752644392
#   (3, 1): 0.00356655123
#   (3, 2): 0.0034975863051
#   (3, 3): 0.0034273171508999996
#   (3, 4): 0.003336370929
#   (3, 5): 0.0031993126830000005
#   (3, 6): 0.0030531054132
#   (3, 7): 0.0029361103880999996
#   (3, 8): 0.0027957841179
#   (3, 9): 0.0026178374244
#   (3, 10): 0.0026060933921999998
#   (3, 11): 0.0024847220564999995
#   (3, 12): 0.0024768300744000002
#   (3, 13): 0.0025240200743999997
#   (3, 14): 0.0025400914929
#   (3, 15): 0.0026397410468999996
#   (3, 16): 0.0010464262673999998
#   (3, 17): 0.0009071987342999998
#   (3, 18): 0.0023779876533
#   (3, 19): 0.0024172075650000006
#   (3, 20): 0.0039061720809000005
#   (3, 21): 0.003945724488899999
#   (3, 22): 0.0024456396597000007
#   (3, 23): 0.0025122650766
#   (3, 24): 0.0026760473883
#   (3, 25): 0.0029396481938999985
#   (3, 26): 0.0030134754579
#   (3, 27): 0.0045105548925
#   (3, 28): 0.003160746951
#   (3, 29): 0.0048252782699999995
#   (3, 30): 0.0035201026448999995
#   (3, 31): 0.0035146695440999996
#   (3, 32): 0.0050392899396
#   (3, 33): 0.0035501720846999995
#   (3, 34): 0.004997208057899999
#   (3, 35): 0.0047285950593
#   (3, 36): 0.004769447943599999
#   (3, 37): 0.0033551184642
#   (3, 38): 0.0029621103095999997
#   (3, 39): 0.0038914259829
#   (3, 40): 0.0028008045306
#   (3, 41): 0.0016104535703999998
#   (3, 42): 0.0032779607529
#   (3, 43): 0.0033494587199999998
#   (3, 44): 0.0033109028012999996
#   (3, 45): 0.0033556955571
#   (3, 46): 0.0034981112951999994
#   (3, 47): 0.0036711359036999997
#   (3, 48): 0.0036752644392
#   (3, 49): 0.00356655123
#   (3, 50): 0.0034975863051
#   (3, 51): 0.0034273171508999996
#   (3, 52): 0.003336370929
#   (3, 53): 0.0031993126830000005
#   (3, 54): 0.0030531054132
#   (3, 55): 0.0029361103880999996
#   (3, 56): 0.0027957841179
#   (3, 57): 0.0026178374244
#   (3, 58): 0.0026060933921999998
#   (3, 59): 0.0024847220564999995
#   (3, 60): 0.0024768300744000002
#   (3, 61): 0.0025240200743999997
#   (3, 62): 0.0025400914929
#   (3, 63): 0.0026397410468999996
#   (3, 64): 0.0010464262673999998
#   (3, 65): 0.0009071987342999998
#   (3, 66): 0.0023779876533
#   (3, 67): 0.0024172075650000006
#   (3, 68): 0.0039061720809000005
#   (3, 69): 0.003945724488899999
#   (3, 70): 0.0024456396597000007
#   (3, 71): 0.0025122650766
#   (3, 72): 0.0026760473883
#   (3, 73): 0.0029396481938999985
#   (3, 74): 0.0030134754579
#   (3, 75): 0.0045105548925
#   (3, 76): 0.003160746951
#   (3, 77): 0.0048252782699999995
#   (3, 78): 0.0035201026448999995
#   (3, 79): 0.0035146695440999996
#   (3, 80): 0.0050392899396
#   (3, 81): 0.0035501720846999995
#   (3, 82): 0.004997208057899999
#   (3, 83): 0.0047285950593
#   (3, 84): 0.004769447943599999
#   (3, 85): 0.0033551184642
#   (3, 86): 0.0029621103095999997
#   (3, 87): 0.0038914259829
#   (3, 88): 0.0028008045306
#   (3, 89): 0.0016104535703999998
#   (3, 90): 0.0032779607529
#   (3, 91): 0.0033494587199999998
#   (3, 92): 0.0033109028012999996
#   (3, 93): 0.0033556955571
#   (3, 94): 0.0034981112951999994
#   (3, 95): 0.0036711359036999997

# %%
############################---------------------- Define Variables ---------------------############################

# ###################### Normal Operation Scenario ########################
manager.initialize_voltage_square_variables(voltage_name_prefix="v")
manager.initialize_power_variable("pgrid", manager.model.SGrid)
manager.initialize_power_variable("qgrid", manager.model.SGrid)
manager.initialize_power_variable("pline", manager.model.Slines)
manager.initialize_power_variable("qline", manager.model.Slines)
manager.initialize_power_variable("ptransformer", manager.model.STransformers)
manager.initialize_power_variable("qtransformer", manager.model.STransformers)
manager.initialize_power_variable("transformer_curr", manager.model.STransformers)
manager.initialize_der_variables("pder_contr", "pder_curtail_contr", "qder_contr")
manager.initialize_line_square_variables(manager.model.Slines, line_curr_name_prefix="Line_curr")
manager.initialize_line_variables(manager.model.Slines, line_losses_name_prefix = "Line_losses")

ref_bus=0 # THIS MUST BE ADDED AUTOMATICALLY 
for t in manager.model.STimes:
    manager.model.v[ref_bus, t].fix(1)

###################### EV Variables ########################
manager.initialize_ev_variables("pEVch","qEV", "EVsoc")

print(manager.list_variables())
# Out:
# ['v', 'pgrid', 'qgrid', 'pline', 'qline', 'ptransformer', 'qtransformer', 'transformer_curr', 'pder_contr', 'pder_curtail_contr', 'qder_contr', 'Line_curr', 'Line_losses', 'pEVch', 'qEV', 'EVsoc']

# %%
####################-------------------- Line Flow constraints -----------------------#######################

manager.add_line_flow_amplitude_losses_constraint(line_set=manager.model.Slines, current_var=manager.model.Line_curr, losses_var=manager.model.Line_losses, line_flow_losses_con_name_prefix="line_losses")

###################-----------------Curtail DER Power Constrain ------------#######################

def Curtail_DER_Power_rule(model, i, time):
    return (model.pder_curtail_contr[i,time] ==  model.pder_curtail_contr[i,  time].ub - model.pder_contr[i,  time])
manager.model.Curtail_DER_cons = Constraint(manager.model.SDER_contr,manager.model.STimes, rule=Curtail_DER_Power_rule)  # Minimum, Maximum power for Gen

####################-------------------- EV Constrain -----------------------#######################

manager.add_ev_soc_constraint("EV_SOC_cons")
# Fix variables for non-charging times
manager.fix_ev_non_charging_times(model_ev_ch=manager.model.pEVch, model_ev_flex_up=None, model_ev_flex_down=None)

# %%
###################-------------------- Power Flow Constrain -----------------------#######################

manager.add_active_power_flow_df_wos_constraint(manager.model.pder_contr, manager.model.pline, manager.model.ptransformer, manager.model.pgrid, manager.model.pEVch, manager.model.Line_curr, manager.model.transformer_curr, "active_power_flow")
manager.add_reactive_power_flow_df_wos_constraint(manager.model.qder_contr, manager.model.qline, manager.model.qtransformer, manager.model.qgrid, manager.model.qEV, manager.model.Line_curr, manager.model.transformer_curr, "reactive_power_flow")
manager.add_voltage_power_flow_df_wos_constraint(manager.model.pline, manager.model.qline, manager.model.Line_curr, manager.model.v, manager.model.resistance_Parm , manager.model.reactance_Parm, manager.model.Slines, "voltage_lines_pf" )
manager.add_brunch_current_flow_df_wos_equal_constraint(manager.model.pline, manager.model.qline, manager.model.Line_curr, manager.model.v, manager.model.Slines, "current_lines_equal_pf" )
manager.add_voltage_power_flow_df_wos_constraint(manager.model.ptransformer, manager.model.qtransformer, manager.model.transformer_curr, manager.model.v, manager.model.transformer_resistance_Parm, manager.model.transformer_reactance_Parm, manager.model.STransformers, "voltage_transformers_pf" )
manager.add_brunch_current_flow_df_wos_equal_constraint(manager.model.ptransformer, manager.model.qtransformer, manager.model.transformer_curr, manager.model.v, manager.model.STransformers, "current_transformers_equal_pf" )

# %%
####################-------------------- Objective -----------------------#######################

def obj_rule(model):

    losses_term = sum(model.Line_losses[sfrom, sto, time]
                      for time in model.STimes 
                      for sfrom, sto in model.Slines)

    curtail_term = 300*sum(model.pder_curtail_contr[der, time]
                       for der in model.SDER_contr
                       for time in model.STimes)
    
    return losses_term + curtail_term

manager.model.obj = Objective(rule=obj_rule, sense=minimize)

# %%
# Define the solver without syntax issues and include line breaks
solver = SolverFactory('ipopt')

solver.options['max_iter'] = 5000  # Increase the maximum number of iterations
solver.options['tol'] = 1e-10       # Set a smaller tolerance for convergence
solver.options['print_level'] = 5  # Higher levels provide more detailed output (0-12)
solver.options['acceptable_tol'] = 1e-2            # early stopping
# solver.options['output_file'] = 'ipopt_log.txt'  # Save IPOPT log to a file

results = solver.solve(manager.model, tee=True)

# After solving, print the results
print("Status: ", results.solver.status)
print("Termination Condition: ", results.solver.termination_condition)

# Check if the solution is feasible
if results.solver.termination_condition == TerminationCondition.optimal:
    
    print("successful")
    # Extract solver timing (wallclock time)
    solver_time = results.solver.time  # Total solving time in seconds
    print(f"Solver Time: {solver_time} seconds")

else:
    print("Infeasible solution.")
# Out:
# Ipopt 3.14.17: max_iter=5000
# tol=1e-10
# print_level=5
# acceptable_tol=0.01
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.17, running with linear solver MUMPS 5.6.2.
#
# Number of nonzeros in equality constraint Jacobian...:     5740
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      768
#
# Total number of variables............................:     2196
#                      variables with only lower bounds:      192
#                 variables with lower and upper bounds:     1140
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     1824
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  3.2804431e+00 1.21e-02 4.17e+01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  3.2875616e+00 1.21e-02 4.07e+01  -1.0 5.54e-01   2.0 3.72e-03 2.78e-06f  1
#    2  9.3782774e+00 1.20e-02 3.96e+01  -1.0 4.16e-01   1.5 5.03e-03 7.43e-03f  1
#    3  1.1225138e+01 1.20e-02 3.92e+01  -1.0 1.51e+00   1.0 5.70e-03 4.57e-03f  1
#    4  2.4093222e+01 1.14e-02 3.85e+01  -1.0 3.41e-01   1.5 2.80e-02 4.47e-02f  1
#    5  2.4336078e+01 1.05e-02 4.39e+02  -1.0 3.15e-01    -  3.72e-01 8.37e-02f  1
#    6  2.3282451e+01 5.40e-03 8.52e+02  -1.0 9.66e-02    -  8.12e-01 4.85e-01h  1
#    7  2.3169118e+01 5.71e-05 1.84e+03  -1.0 4.59e-02    -  4.09e-01 9.90e-01h  1
#    8  2.2913040e+01 2.27e-05 5.15e+04  -1.0 7.07e-03   2.8 1.00e+00 6.10e-01f  1
#    9  2.2648534e+01 2.65e-05 1.65e+02  -1.0 7.18e-03    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.1536185e+01 2.10e-06 1.86e+03  -1.7 4.64e-03    -  9.91e-01 1.00e+00f  1
#   11  6.4665392e+00 2.85e-06 4.59e-01  -1.7 3.94e-03    -  1.00e+00 1.00e+00f  1
#   12  2.0797206e+00 1.19e-06 5.57e+02  -3.8 1.57e-03    -  8.39e-01 8.28e-01f  1
#   13  1.0069428e+00 3.57e-07 6.02e+02  -3.8 5.30e-04    -  8.18e-01 7.67e-01f  1
#   14  6.8684605e-01 4.39e-07 5.66e-01  -3.8 6.63e-04    -  1.00e+00 1.00e+00f  1
#   15  6.8225055e-01 1.05e-06 1.36e-04  -3.8 1.77e-03    -  1.00e+00 1.00e+00h  1
#   16  6.2908149e-01 1.85e-06 6.02e+01  -5.7 2.37e-03    -  8.60e-01 1.00e+00f  1
#   17  6.2373472e-01 1.84e-05 3.73e+01  -5.7 1.48e-02    -  3.79e-01 1.00e+00h  1
#   18  6.2169265e-01 1.06e-05 2.14e+01  -5.7 1.45e-02    -  4.28e-01 1.00e+00h  1
#   19  6.2050083e-01 3.89e-06 1.02e+01  -5.7 1.04e-02    -  5.24e-01 9.62e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  6.1961697e-01 1.08e-05 4.42e+00  -5.7 1.37e-02    -  5.65e-01 1.00e+00f  1
#   21  6.1932795e-01 6.38e-06 1.65e-04  -5.7 1.06e-02    -  1.00e+00 1.00e+00h  1
#   22  6.1932428e-01 8.03e-08 7.95e-06  -5.7 6.79e-04    -  1.00e+00 1.00e+00h  1
#   23  6.1848052e-01 2.09e-06 5.70e-01  -8.6 1.31e-02    -  5.64e-01 4.56e-01h  1
#   24  6.1809553e-01 1.81e-06 2.99e-01  -8.6 7.76e-03    -  3.64e-01 3.86e-01h  1
#   25  6.1762708e-01 1.57e-06 5.50e-02  -8.6 5.54e-03    -  7.70e-01 8.38e-01h  1
#   26  6.1754755e-01 9.46e-07 3.18e-02  -8.6 1.76e-03    -  8.27e-01 9.04e-01h  1
#   27  6.1754002e-01 8.32e-07 6.78e-03  -8.6 9.12e-04    -  8.86e-01 1.00e+00f  1
#   28  6.1754001e-01 1.07e-06 1.02e-01  -8.6 2.01e-03    -  8.33e-01 5.00e-01h  2
#   29  6.1754001e-01 1.06e-06 1.35e-01  -8.6 1.71e-03    -  8.02e-02 5.89e-03h  8
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  6.1754173e-01 5.45e-07 6.30e-01  -8.6 7.38e-04    -  4.43e-02 1.00e+00h  1
#   31  6.1754255e-01 1.16e-07 3.56e-02  -8.6 3.41e-04    -  7.63e-01 1.00e+00h  1
#   32  6.1754263e-01 1.27e-07 1.04e-02  -8.6 5.24e-04    -  4.73e-01 5.00e-01h  2
#   33  6.1754299e-01 3.07e-08 1.49e-02  -8.6 1.75e-04    -  7.56e-01 1.00e+00h  1
#   34  6.1754314e-01 5.37e-13 5.01e-08  -8.6 7.34e-07    -  1.00e+00 1.00e+00h  1
#   35  6.1754314e-01 1.58e-15 7.64e-10  -8.6 3.97e-08    -  1.00e+00 1.00e+00h  1
#   36  6.1754093e-01 4.36e-10 8.82e-05 -11.0 5.02e-05    -  9.93e-01 9.89e-01f  1
# In iteration 36, 1 Slack too small, adjusting variable bound
#   37  6.1754091e-01 1.01e-10 7.60e-03 -11.0 8.56e-06    -  5.03e-01 9.08e-01f  1
# In iteration 37, 1 Slack too small, adjusting variable bound
#   38  6.1754090e-01 2.47e-11 1.77e-03 -11.0 2.47e-06    -  1.00e+00 7.93e-01h  1
#   39  6.1754090e-01 8.97e-13 1.20e-11 -11.0 9.47e-07    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 39
#
#                                    (scaled)                 (unscaled)
# Objective...............:   2.0584696797857119e-01    6.1754090393571359e-01
# Dual infeasibility......:   1.1962622006266104e-11    3.5887866018798313e-11
# Constraint violation....:   8.9723874065347503e-13    8.9723874065347503e-13
# Variable bound violation:   1.1024639645640377e-08    1.1024639645640377e-08
# Complementarity.........:   2.8208599600376792e-11    8.4625798801130382e-11
# Overall NLP error.......:   2.8208599600376792e-11    8.4625798801130382e-11
#
#
# Number of objective function evaluations             = 51
# Number of objective gradient evaluations             = 40
# Number of equality constraint evaluations            = 51
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 40
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 39
# Total seconds in IPOPT                               = 0.047
#
# EXIT: Optimal Solution Found.
# Status:  ok
# Termination Condition:  optimal
# successful
# Solver Time: 0.06360888481140137 seconds

# %%
print("Objective value:", value(manager.model.obj))

manager.results.wrapper_var_results()
print(manager.results.list())
print(manager.results.EVsoc.head())
# Out:
# Objective value: 0.6175409039357138
# ['EVsoc', 'Line_curr', 'Line_losses', 'pEVch', 'pder_contr', 'pder_curtail_contr', 'pgrid', 'pline', 'ptransformer', 'qEV', 'qder_contr', 'qgrid', 'qline', 'qtransformer', 'transformer_curr', 'v']
#          2         3
# 0  0.03192  0.017862
# 1  0.03192  0.019005
# 2  0.03192  0.020200
# 3  0.03192  0.020200
# 4  0.03192  0.020200

# %%
manager.plot_fun.result_df_plot(manager.results.pEVch*manager.anc_Vars.S_Base*1000,"EV Charge Power", "time [hh:mm]" ,"Active Power [kW]")
manager.plot_fun.result_df_plot(manager.results.EVsoc*manager.anc_Vars.S_Base*1000,"EV SoC", "Time (hh-mm)" ,"SoC (kWh)",label="Yes")
manager.plot_fun.result_df_plot(manager.results.Line_losses*manager.anc_Vars.I_base*1000,"Line Losses", "Time (hh-mm)" ,"Losses (Joule)",label="Yes")
manager.plot_fun.result_df_plot(manager.results.qEV*manager.anc_Vars.S_Base*1000,"EV reactive power", "Time (hh-mm)" ,"Q (kVAr)",label="Yes")
manager.plot_fun.result_df_plot(manager.results.pder_contr*manager.anc_Vars.S_Base*1000,"Pder_contrl", "Time (hh-mm)" ,"P (kW)",label="Yes")
manager.plot_fun.result_df_plot(manager.results.pder_curtail_contr*manager.anc_Vars.S_Base*1000,"Pder_contrl_curtail", "Time (hh-mm)" ,"P (kW)",label="Yes")
manager.plot_fun.result_df_plot(manager.results.qder_contr*manager.anc_Vars.S_Base*1000,"Qder_contrl_reactive_power", "Time (hh-mm)" ,"Q (kVAr)",label="Yes")
manager.plot_fun.result_df_plot(np.sqrt(manager.results.v),"Voltage", "Time (hh-mm)" ,"Voltage (p.u.)", label="Yes")

# %% [markdown]
# ### This is the same DistFlow Model but with SOCP relaxation and solve using GUROBI

# %%
net = pn.simple_four_bus_system()
net.bus['max_vm_pu'] = 1.05
net.bus['min_vm_pu'] = 0.95

# %%
sys.path.append('../v8_Main/src')

from Manager import *
manager = Manager(net=net)
manager.addTime(timeframe=48,time_interval=30) ## At objective, timeframe(in hours) , time-interval(in minutes)
manager.anc_Vars.System_Data_DER.loc[0,'Controllable']=True

# %%
#######################------------------- Easy method to get the admittance Matrix ----------------####################33
# Run a power flow calculation

pp.runpp(net)

# Access the Y-bus matrix from the network results
Ybus = net["_ppc"]["internal"]["Ybus"]
# print("Y-bus matrix:\n", Ybus.todense())

# Convert the sparse Y-bus matrix to a dense format and then to a DataFrame
Y_bus_df = pd.DataFrame(Ybus.todense())

# Add row and column labels if needed
Y_bus_df.index = net.bus.index
Y_bus_df.columns = net.bus.index
# print(Y_bus_df)
################### OR ######################

Ybus = build_ybus(net)

### Generate load/DER time scale data
file_path2 = '../Data/profiles/pv_load_profiles/Profiles_for_testing.xlsx'
profiles = pd.read_excel(file_path2)
profiles = pd.concat([profiles]*2, ignore_index=True)

# %%
# Custom Add EVs since in pandapower EVs are not available

manager.anc_Vars.addEV(node=2,P_min_ch=0,P_max_ch=11,Qmin=-3.616 , Qmax=3.616, costh_EV=1, P_control="controllable" , Q_control="controllable" , V2G="False", EV_EC=56, EV_SoC_init=57, EV_SoC_end=100, EV_SoC_min=35, EV_SoC_max=80, EV_cons=17,arrival=[31,31+48],departure=[13,13+48],distance=[1,1])
manager.anc_Vars.addEV(node=3,P_min_ch=0,P_max_ch=11,Qmin=-3.616 , Qmax=3.616, costh_EV=1, P_control="controllable" , Q_control="controllable" , V2G="False", EV_EC=56, EV_SoC_init=30, EV_SoC_end=100, EV_SoC_min=30, EV_SoC_max=80, EV_cons=17,arrival=[36,36+48],departure=[3,3+48],distance=[20,20])

# print(manager.anc_Vars.system_data_ev)
# print(manager.anc_Vars.system_data_ev_char)

# %%
# This code initialize/create all the needed sets in pyomo model.
manager.initialize_sets()  # Initialize sets

print(manager.list_sets())
# manager.show_set("Sbuses")
# manager.show_set("SGrid")
# manager.show_set("SDER_contr")
# manager.show_set("SDER_uncontr")
# manager.show_set("SLoadbuses")
# manager.show_set("Slines")
# manager.show_set("STimes")
# manager.show_set("SEVbuses")
# manager.show_set("SDistance_ind")
# Out:
# ['Sbuses', 'SGrid', 'SDER_contr', 'SDER_uncontr', 'SLoadbuses', 'Slines', 'STransformers', 'STimes', 'SEVbuses', 'SDistance_ind', 'Sdownstream', 'Supstream', 'Sdownstream_transformer', 'Supstream_transformer', 'Sreverse_lines', 'Sreverse_transformers']

# %%
############################---------------------- Define Parameters ---------------------############################

# Why defined parameters? if we defined parameters instead of using for example panda dataframe then we can rerun the model without the need to 
# rebuild the constraints during the solving it automatically get the new parameters so the steps for a load modification example is the following
# 1) Define the load profile dataframe, 2) Run variables 3) Run parameters, 4)Build model, 5) Solve optimization, 6)Change load profile , 7) Run parameters ,8) Solve optimization
# MUTABLE=TRUE is the function parameter that allow this

manager.load_profile_param(profiles, "Load_P", "Load_Q") # This create Load_P and Load_Q profile which is equal to PandapowerPower*p.u. [from profiles files]
manager.line_param(Y_bus_df, "resistance_Parm", "reactance_Parm", "admitt_mat_Parm_real", "admitt_mat_Parm_imag")
manager.transformer_param("transformer_resistance_Parm", "transformer_reactance_Parm") # This create resistance and reactance parameters for transformers

############ EV #################
manager.initialize_ev_params("ev_min_ch_param", "ev_max_ch_param", "EVinit_SOC", "EVend_SOC_param", "EV_SoC_min_param", "EV_SoC_max_param", "EV_capacity_param")
manager.initialize_ev_char_params("ev_arrival_time_param", "ev_departure_time_param", "ev_trip_distance_param", "EV_SoC_min_departure_param",  "EV_trip_energy_needs_param", "EV_available_param" )
manager.initialize_ev_min_soc_timeseries("EV_SoC_min_overtime_param")

############ DER #################
manager.der_profile_param(profiles, "unctrl_PV_gen_P", "unctrl_PV_gen_Q", "ctrl_PV_gen_P", "ctrl_PV_gen_Q")

print(manager.list_parameters())
manager.show_parameter("Load_P")
# Out:
# ['Load_P', 'Load_Q', 'resistance_Parm', 'reactance_Parm', 'admitt_mat_Parm_real', 'admitt_mat_Parm_imag', 'transformer_resistance_Parm', 'transformer_reactance_Parm', 'ev_min_ch_param', 'ev_max_ch_param', 'EVinit_SOC', 'EVend_SOC_param', 'EV_SoC_min_param', 'EV_SoC_max_param', 'EV_capacity_param', 'ev_arrival_time_param', 'ev_departure_time_param', 'ev_trip_distance_param', 'EV_SoC_min_departure_param', 'EV_trip_energy_needs_param', 'EV_available_param', 'EV_SoC_min_overtime_param', 'unctrl_PV_gen_P', 'ctrl_PV_gen_P', 'unctrl_PV_gen_Q', 'ctrl_PV_gen_Q']
# Variable Load_P:
#   (2, 0): 0.0036752644392
#   (2, 1): 0.00356655123
#   (2, 2): 0.0034975863051
#   (2, 3): 0.0034273171508999996
#   (2, 4): 0.003336370929
#   (2, 5): 0.0031993126830000005
#   (2, 6): 0.0030531054132
#   (2, 7): 0.0029361103880999996
#   (2, 8): 0.0027957841179
#   (2, 9): 0.0026178374244
#   (2, 10): 0.0026060933921999998
#   (2, 11): 0.0024847220564999995
#   (2, 12): 0.0024768300744000002
#   (2, 13): 0.0025240200743999997
#   (2, 14): 0.0025400914929
#   (2, 15): 0.0026397410468999996
#   (2, 16): 0.0010464262673999998
#   (2, 17): 0.0009071987342999998
#   (2, 18): 0.0023779876533
#   (2, 19): 0.0024172075650000006
#   (2, 20): 0.0039061720809000005
#   (2, 21): 0.003945724488899999
#   (2, 22): 0.0024456396597000007
#   (2, 23): 0.0025122650766
#   (2, 24): 0.0026760473883
#   (2, 25): 0.0029396481938999985
#   (2, 26): 0.0030134754579
#   (2, 27): 0.0045105548925
#   (2, 28): 0.003160746951
#   (2, 29): 0.0048252782699999995
#   (2, 30): 0.0035201026448999995
#   (2, 31): 0.0035146695440999996
#   (2, 32): 0.0050392899396
#   (2, 33): 0.0035501720846999995
#   (2, 34): 0.004997208057899999
#   (2, 35): 0.0047285950593
#   (2, 36): 0.004769447943599999
#   (2, 37): 0.0033551184642
#   (2, 38): 0.0029621103095999997
#   (2, 39): 0.0038914259829
#   (2, 40): 0.0028008045306
#   (2, 41): 0.0016104535703999998
#   (2, 42): 0.0032779607529
#   (2, 43): 0.0033494587199999998
#   (2, 44): 0.0033109028012999996
#   (2, 45): 0.0033556955571
#   (2, 46): 0.0034981112951999994
#   (2, 47): 0.0036711359036999997
#   (2, 48): 0.0036752644392
#   (2, 49): 0.00356655123
#   (2, 50): 0.0034975863051
#   (2, 51): 0.0034273171508999996
#   (2, 52): 0.003336370929
#   (2, 53): 0.0031993126830000005
#   (2, 54): 0.0030531054132
#   (2, 55): 0.0029361103880999996
#   (2, 56): 0.0027957841179
#   (2, 57): 0.0026178374244
#   (2, 58): 0.0026060933921999998
#   (2, 59): 0.0024847220564999995
#   (2, 60): 0.0024768300744000002
#   (2, 61): 0.0025240200743999997
#   (2, 62): 0.0025400914929
#   (2, 63): 0.0026397410468999996
#   (2, 64): 0.0010464262673999998
#   (2, 65): 0.0009071987342999998
#   (2, 66): 0.0023779876533
#   (2, 67): 0.0024172075650000006
#   (2, 68): 0.0039061720809000005
#   (2, 69): 0.003945724488899999
#   (2, 70): 0.0024456396597000007
#   (2, 71): 0.0025122650766
#   (2, 72): 0.0026760473883
#   (2, 73): 0.0029396481938999985
#   (2, 74): 0.0030134754579
#   (2, 75): 0.0045105548925
#   (2, 76): 0.003160746951
#   (2, 77): 0.0048252782699999995
#   (2, 78): 0.0035201026448999995
#   (2, 79): 0.0035146695440999996
#   (2, 80): 0.0050392899396
#   (2, 81): 0.0035501720846999995
#   (2, 82): 0.004997208057899999
#   (2, 83): 0.0047285950593
#   (2, 84): 0.004769447943599999
#   (2, 85): 0.0033551184642
#   (2, 86): 0.0029621103095999997
#   (2, 87): 0.0038914259829
#   (2, 88): 0.0028008045306
#   (2, 89): 0.0016104535703999998
#   (2, 90): 0.0032779607529
#   (2, 91): 0.0033494587199999998
#   (2, 92): 0.0033109028012999996
#   (2, 93): 0.0033556955571
#   (2, 94): 0.0034981112951999994
#   (2, 95): 0.0036711359036999997
#   (3, 0): 0.0036752644392
#   (3, 1): 0.00356655123
#   (3, 2): 0.0034975863051
#   (3, 3): 0.0034273171508999996
#   (3, 4): 0.003336370929
#   (3, 5): 0.0031993126830000005
#   (3, 6): 0.0030531054132
#   (3, 7): 0.0029361103880999996
#   (3, 8): 0.0027957841179
#   (3, 9): 0.0026178374244
#   (3, 10): 0.0026060933921999998
#   (3, 11): 0.0024847220564999995
#   (3, 12): 0.0024768300744000002
#   (3, 13): 0.0025240200743999997
#   (3, 14): 0.0025400914929
#   (3, 15): 0.0026397410468999996
#   (3, 16): 0.0010464262673999998
#   (3, 17): 0.0009071987342999998
#   (3, 18): 0.0023779876533
#   (3, 19): 0.0024172075650000006
#   (3, 20): 0.0039061720809000005
#   (3, 21): 0.003945724488899999
#   (3, 22): 0.0024456396597000007
#   (3, 23): 0.0025122650766
#   (3, 24): 0.0026760473883
#   (3, 25): 0.0029396481938999985
#   (3, 26): 0.0030134754579
#   (3, 27): 0.0045105548925
#   (3, 28): 0.003160746951
#   (3, 29): 0.0048252782699999995
#   (3, 30): 0.0035201026448999995
#   (3, 31): 0.0035146695440999996
#   (3, 32): 0.0050392899396
#   (3, 33): 0.0035501720846999995
#   (3, 34): 0.004997208057899999
#   (3, 35): 0.0047285950593
#   (3, 36): 0.004769447943599999
#   (3, 37): 0.0033551184642
#   (3, 38): 0.0029621103095999997
#   (3, 39): 0.0038914259829
#   (3, 40): 0.0028008045306
#   (3, 41): 0.0016104535703999998
#   (3, 42): 0.0032779607529
#   (3, 43): 0.0033494587199999998
#   (3, 44): 0.0033109028012999996
#   (3, 45): 0.0033556955571
#   (3, 46): 0.0034981112951999994
#   (3, 47): 0.0036711359036999997
#   (3, 48): 0.0036752644392
#   (3, 49): 0.00356655123
#   (3, 50): 0.0034975863051
#   (3, 51): 0.0034273171508999996
#   (3, 52): 0.003336370929
#   (3, 53): 0.0031993126830000005
#   (3, 54): 0.0030531054132
#   (3, 55): 0.0029361103880999996
#   (3, 56): 0.0027957841179
#   (3, 57): 0.0026178374244
#   (3, 58): 0.0026060933921999998
#   (3, 59): 0.0024847220564999995
#   (3, 60): 0.0024768300744000002
#   (3, 61): 0.0025240200743999997
#   (3, 62): 0.0025400914929
#   (3, 63): 0.0026397410468999996
#   (3, 64): 0.0010464262673999998
#   (3, 65): 0.0009071987342999998
#   (3, 66): 0.0023779876533
#   (3, 67): 0.0024172075650000006
#   (3, 68): 0.0039061720809000005
#   (3, 69): 0.003945724488899999
#   (3, 70): 0.0024456396597000007
#   (3, 71): 0.0025122650766
#   (3, 72): 0.0026760473883
#   (3, 73): 0.0029396481938999985
#   (3, 74): 0.0030134754579
#   (3, 75): 0.0045105548925
#   (3, 76): 0.003160746951
#   (3, 77): 0.0048252782699999995
#   (3, 78): 0.0035201026448999995
#   (3, 79): 0.0035146695440999996
#   (3, 80): 0.0050392899396
#   (3, 81): 0.0035501720846999995
#   (3, 82): 0.004997208057899999
#   (3, 83): 0.0047285950593
#   (3, 84): 0.004769447943599999
#   (3, 85): 0.0033551184642
#   (3, 86): 0.0029621103095999997
#   (3, 87): 0.0038914259829
#   (3, 88): 0.0028008045306
#   (3, 89): 0.0016104535703999998
#   (3, 90): 0.0032779607529
#   (3, 91): 0.0033494587199999998
#   (3, 92): 0.0033109028012999996
#   (3, 93): 0.0033556955571
#   (3, 94): 0.0034981112951999994
#   (3, 95): 0.0036711359036999997

# %%
############################---------------------- Define Variables ---------------------############################

# ###################### Normal Operation Scenario ########################
manager.initialize_voltage_square_variables(voltage_name_prefix="v")
manager.initialize_power_variable("pgrid", manager.model.SGrid)
manager.initialize_power_variable("qgrid", manager.model.SGrid)
manager.initialize_power_variable("pline", manager.model.Slines)
manager.initialize_power_variable("qline", manager.model.Slines)
manager.initialize_power_variable("ptransformer", manager.model.STransformers)
manager.initialize_power_variable("qtransformer", manager.model.STransformers)
manager.initialize_power_variable("transformer_curr", manager.model.STransformers)
manager.initialize_der_variables("pder_contr", "pder_curtail_contr", "qder_contr")
manager.initialize_line_square_variables(manager.model.Slines, line_curr_name_prefix="Line_curr")
manager.initialize_line_variables(manager.model.Slines, line_losses_name_prefix = "Line_losses")

ref_bus=0 # THIS MUST BE ADDED AUTOMATICALLY 
for t in manager.model.STimes:
    manager.model.v[ref_bus, t].fix(1)

###################### EV Variables ########################
manager.initialize_ev_variables("pEVch","qEV", "EVsoc")

print(manager.list_variables())
# Out:
# ['v', 'pgrid', 'qgrid', 'pline', 'qline', 'ptransformer', 'qtransformer', 'transformer_curr', 'pder_contr', 'pder_curtail_contr', 'qder_contr', 'Line_curr', 'Line_losses', 'pEVch', 'qEV', 'EVsoc']

# %%
########### Line Flow constraints ########################

manager.add_line_flow_amplitude_losses_constraint(line_set=manager.model.Slines, current_var=manager.model.Line_curr, losses_var=manager.model.Line_losses, line_flow_losses_con_name_prefix="line_losses")

###################-----------------Curtail DER Power Constrain ------------#######################

def Curtail_DER_Power_rule(model, i, time):
    return (model.pder_curtail_contr[i,time] ==  model.pder_curtail_contr[i,  time].ub - model.pder_contr[i,  time])
manager.model.Curtail_DER_cons = Constraint(manager.model.SDER_contr,manager.model.STimes, rule=Curtail_DER_Power_rule)  # Minimum, Maximum power for Gen

####################-------------------- EV Constrain -----------------------#######################
manager.add_ev_soc_constraint("EV_SOC_cons")
# Fix variables for non-charging times
manager.fix_ev_non_charging_times(model_ev_ch=manager.model.pEVch, model_ev_flex_up=None, model_ev_flex_down=None)

# %%
###################-------------------- Power Flow Constrain -----------------------#######################
manager.add_active_power_flow_df_wos_constraint(manager.model.pder_contr, manager.model.pline, manager.model.ptransformer, manager.model.pgrid, manager.model.pEVch, manager.model.Line_curr, manager.model.transformer_curr, "active_power_flow")
manager.add_reactive_power_flow_df_wos_constraint(manager.model.qder_contr, manager.model.qline, manager.model.qtransformer, manager.model.qgrid, manager.model.qEV, manager.model.Line_curr, manager.model.transformer_curr, "reactive_power_flow")
manager.add_voltage_power_flow_df_wos_constraint(manager.model.pline, manager.model.qline, manager.model.Line_curr, manager.model.v, manager.model.resistance_Parm , manager.model.reactance_Parm, manager.model.Slines, "voltage_lines_pf" )
manager.add_brunch_current_flow_df_wos_SOCP_constraint(manager.model.pline, manager.model.qline, manager.model.Line_curr, manager.model.v, manager.model.Slines, "current_lines_equal_pf" )
manager.add_voltage_power_flow_df_wos_constraint(manager.model.ptransformer, manager.model.qtransformer, manager.model.transformer_curr, manager.model.v, manager.model.transformer_resistance_Parm, manager.model.transformer_reactance_Parm, manager.model.STransformers, "voltage_transformers_pf" )
manager.add_brunch_current_flow_df_wos_SOCP_constraint(manager.model.ptransformer, manager.model.qtransformer, manager.model.transformer_curr, manager.model.v, manager.model.STransformers, "current_transformers_equal_pf" )

# %%
####################-------------------- Objective -----------------------#######################

def obj_rule(model):

    losses_term = sum(model.Line_losses[sfrom, sto, time]
                      for time in model.STimes 
                      for sfrom, sto in model.Slines)

    curtail_term = 300*sum(model.pder_curtail_contr[der, time]
                       for der in model.SDER_contr
                       for time in model.STimes)
    
    return losses_term + curtail_term

manager.model.obj = Objective(rule=obj_rule, sense=minimize)

# %%
# Define the solver without syntax issues and include line breaks
solver = SolverFactory('gurobi')

results = solver.solve(manager.model, tee=True)

# After solving, print the results
print("Status: ", results.solver.status)
print("Termination Condition: ", results.solver.termination_condition)

# Check if the solution is feasible
if results.solver.termination_condition == TerminationCondition.optimal:
    
    print("successful")
    # Extract solver timing (wallclock time)
    # solver_time = results.solver.time
    # print(f"Solver time: {solver_time:.2f} seconds")

else:
    print("Infeasible solution.")
# Out:
# Read LP format model from file /var/folders/th/2f9h317n53n6jdqrwm4cjwt40000gn/T/tmpm57pvi1y.pyomo.lp
# Reading time = 0.00 seconds
# x1: 1536 rows, 2196 columns, 4684 nonzeros
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M4 Max
# Thread count: 14 physical cores, 14 logical processors, using up to 14 threads
#
# Optimize a model with 1536 rows, 2196 columns and 4684 nonzeros
# Model fingerprint: 0xe84a9e7d
# Model has 288 quadratic constraints
# Coefficient statistics:
#   Matrix range     [3e-02, 4e+00]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+02]
#   Bounds range     [3e-07, 1e+00]
#   RHS range        [3e-07, 1e+00]
# Presolve removed 663 rows and 725 columns
# Presolve time: 0.00s
# Presolved: 1449 rows, 2047 columns, 4832 nonzeros
# Presolved model has 288 second-order cone constraints
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 5.473e+03
#  Factor NZ  : 1.283e+04 (roughly 2 MB of memory)
#  Factor Ops : 1.410e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -2.26469674e+05 -1.22597474e+04  9.58e+01 5.20e+02  9.58e+02     0s
#    1  -2.82287500e+04 -4.79491628e+04  7.49e+00 3.00e+01  8.46e+01     0s
#    2  -3.83196233e+03 -1.10698096e+04  8.66e-01 8.66e-03  9.94e+00     0s
#    3  -8.11357048e+02 -3.35818941e+03  1.85e-01 9.30e-04  2.25e+00     0s
#    4  -7.59733681e+01 -7.71718652e+02  1.90e-02 7.25e-05  3.41e-01     0s
#    5  -6.57434052e+00 -2.49653365e+02  2.19e-03 1.99e-05  9.53e-02     0s
#    6   1.08911232e+00 -5.90575996e+00  1.48e-05 4.62e-07  2.58e-03     0s
#    7   3.39352365e-01 -1.11861952e+00  1.63e-11 8.31e-08  5.30e-04     0s
#    8   5.93757822e-02 -8.15901900e-02  2.22e-12 4.01e-09  5.12e-05     0s
#    9   3.14558868e-02 -9.00913708e-04  6.81e-12 6.86e-10  1.18e-05     0s
#   10   2.62110483e-02  9.99209349e-03  6.02e-11 3.15e-10  5.89e-06     0s
#   11   2.30475886e-02  1.66952492e-02  4.31e-11 1.23e-10  2.31e-06     0s
#   12   2.18839306e-02  2.06090366e-02  1.24e-10 1.31e-10  4.63e-07     0s
#   13   2.13126014e-02  2.11263142e-02  1.04e-09 7.88e-10  6.77e-08     0s
#   14   2.12349206e-02  2.12060218e-02  3.59e-09 3.65e-09  1.05e-08     0s
#
# Barrier solved model in 14 iterations and 0.01 seconds (0.01 work units)
# Optimal objective 2.12349206e-02
#
# Status:  ok
# Termination Condition:  optimal
# successful

# %%
print("Objective value:", value(manager.model.obj))

manager.results.wrapper_var_results()
print(manager.results.list())
print(manager.results.EVsoc.head())
# Out:
# Objective value: 0.021234920595720692
# ['EVsoc', 'Line_curr', 'Line_losses', 'pEVch', 'pder_contr', 'pder_curtail_contr', 'pgrid', 'pline', 'ptransformer', 'qEV', 'qder_contr', 'qgrid', 'qline', 'qtransformer', 'transformer_curr', 'v']
#           2         3
# 0  0.031920  0.017863
# 1  0.031920  0.019006
# 2  0.031920  0.020200
# 3  0.031921  0.020200
# 4  0.031921  0.020200

# %%
manager.plot_fun.result_df_plot(manager.results.pEVch*manager.anc_Vars.S_Base*1000,"EV Charge Power", "time [hh:mm]" ,"Active Power [kW]")
manager.plot_fun.result_df_plot(manager.results.EVsoc*manager.anc_Vars.S_Base*1000,"EV SoC", "Time (hh-mm)" ,"SoC (kWh)",label="Yes")
manager.plot_fun.result_df_plot(manager.results.Line_losses*manager.anc_Vars.I_base*1000,"Line Losses", "Time (hh-mm)" ,"Losses (Joule)",label="Yes")
manager.plot_fun.result_df_plot(manager.results.qEV*manager.anc_Vars.S_Base*1000,"EV reactive power", "Time (hh-mm)" ,"Q (kVAr)",label="Yes")
manager.plot_fun.result_df_plot(manager.results.pder_contr*manager.anc_Vars.S_Base*1000,"Pder_contrl", "Time (hh-mm)" ,"P (kW)",label="Yes")
manager.plot_fun.result_df_plot(manager.results.pder_curtail_contr*manager.anc_Vars.S_Base*1000,"Pder_contrl_curtail", "Time (hh-mm)" ,"P (kW)",label="Yes")
manager.plot_fun.result_df_plot(manager.results.qder_contr*manager.anc_Vars.S_Base*1000,"Qder_contrl_reactive_power", "Time (hh-mm)" ,"Q (kVAr)",label="Yes")
manager.plot_fun.result_df_plot(np.sqrt(manager.results.v),"Voltage", "Time (hh-mm)" ,"Voltage (p.u.)", label="Yes")

# %%
from pyomo.environ import value

for idx in manager.model.current_lines_equal_pf:
    c = manager.model.current_lines_equal_pf[idx]
    lhs = value(c.body)
    rhs = value(c.upper) if c.has_ub() else None 
    print(f"LHS = {lhs:.8e}    RHS = {rhs:.8e}    Violation = {abs(lhs - rhs):.2e}")

for idx in manager.model.current_transformers_equal_pf:
    print(idx)
    c = manager.model.current_transformers_equal_pf[idx]
    lhs = value(c.body)
    rhs = value(c.upper) if c.has_ub() else None 
    print(f"LHS = {lhs:.8e}    RHS = {rhs:.8e}    Violation = {abs(lhs - rhs):.2e}")
# Out:
# LHS = -1.98195669e-08    RHS = 0.00000000e+00    Violation = 1.98e-08
# LHS = -2.00964979e-08    RHS = 0.00000000e+00    Violation = 2.01e-08
# LHS = -2.02483125e-08    RHS = 0.00000000e+00    Violation = 2.02e-08
# LHS = -2.14393873e-08    RHS = 0.00000000e+00    Violation = 2.14e-08
# LHS = -2.89773805e-08    RHS = 0.00000000e+00    Violation = 2.90e-08
# LHS = -2.83689118e-08    RHS = 0.00000000e+00    Violation = 2.84e-08
# LHS = -2.72114352e-08    RHS = 0.00000000e+00    Violation = 2.72e-08
# LHS = -2.59504912e-08    RHS = 0.00000000e+00    Violation = 2.60e-08
# LHS = -2.41389348e-08    RHS = 0.00000000e+00    Violation = 2.41e-08
# LHS = -2.16504956e-08    RHS = 0.00000000e+00    Violation = 2.17e-08
# LHS = -2.14882150e-08    RHS = 0.00000000e+00    Violation = 2.15e-08
# LHS = -2.11525858e-08    RHS = 0.00000000e+00    Violation = 2.12e-08
# LHS = -1.67142408e-08    RHS = 0.00000000e+00    Violation = 1.67e-08
# LHS = -1.70498307e-08    RHS = 0.00000000e+00    Violation = 1.70e-08
# LHS = -5.07038533e-09    RHS = 0.00000000e+00    Violation = 5.07e-09
# LHS = -1.07010813e-08    RHS = 0.00000000e+00    Violation = 1.07e-08
# LHS = -2.44766734e-08    RHS = 0.00000000e+00    Violation = 2.45e-08
# LHS = -3.25335020e-08    RHS = 0.00000000e+00    Violation = 3.25e-08
# LHS = -3.79890375e-08    RHS = 0.00000000e+00    Violation = 3.80e-08
# LHS = -1.47894183e-08    RHS = 0.00000000e+00    Violation = 1.48e-08
# LHS = -3.22015106e-08    RHS = 0.00000000e+00    Violation = 3.22e-08
# LHS = -1.56227021e-08    RHS = 0.00000000e+00    Violation = 1.56e-08
# LHS = -2.83960634e-08    RHS = 0.00000000e+00    Violation = 2.84e-08
# LHS = -3.37396905e-08    RHS = 0.00000000e+00    Violation = 3.37e-08
# LHS = -3.67729547e-08    RHS = 0.00000000e+00    Violation = 3.68e-08
# LHS = -3.31896963e-08    RHS = 0.00000000e+00    Violation = 3.32e-08
# LHS = -2.74431207e-08    RHS = 0.00000000e+00    Violation = 2.74e-08
# LHS = -1.30617259e-08    RHS = 0.00000000e+00    Violation = 1.31e-08
# LHS = -1.23752562e-08    RHS = 0.00000000e+00    Violation = 1.24e-08
# LHS = -4.88252519e-08    RHS = 0.00000000e+00    Violation = 4.88e-08
# LHS = -3.68846395e-08    RHS = 0.00000000e+00    Violation = 3.69e-08
# LHS = -4.05743960e-07    RHS = 0.00000000e+00    Violation = 4.06e-07
# LHS = -4.35370664e-08    RHS = 0.00000000e+00    Violation = 4.35e-08
# LHS = -4.45885420e-08    RHS = 0.00000000e+00    Violation = 4.46e-08
# LHS = -1.76497545e-08    RHS = 0.00000000e+00    Violation = 1.76e-08
# LHS = -1.41707966e-08    RHS = 0.00000000e+00    Violation = 1.42e-08
# LHS = -2.61418613e-08    RHS = 0.00000000e+00    Violation = 2.61e-08
# LHS = -2.96346066e-08    RHS = 0.00000000e+00    Violation = 2.96e-08
# LHS = -2.99549128e-08    RHS = 0.00000000e+00    Violation = 3.00e-08
# LHS = -2.01388359e-08    RHS = 0.00000000e+00    Violation = 2.01e-08
# LHS = -3.02195808e-08    RHS = 0.00000000e+00    Violation = 3.02e-08
# LHS = -3.44629302e-08    RHS = 0.00000000e+00    Violation = 3.45e-08
# LHS = -3.23699008e-08    RHS = 0.00000000e+00    Violation = 3.24e-08
# LHS = -2.33053836e-08    RHS = 0.00000000e+00    Violation = 2.33e-08
# LHS = -2.75392623e-08    RHS = 0.00000000e+00    Violation = 2.75e-08
# LHS = -2.27293586e-08    RHS = 0.00000000e+00    Violation = 2.27e-08
# LHS = -1.65268793e-08    RHS = 0.00000000e+00    Violation = 1.65e-08
# LHS = -1.63745072e-08    RHS = 0.00000000e+00    Violation = 1.64e-08
# LHS = -1.63895587e-08    RHS = 0.00000000e+00    Violation = 1.64e-08
# LHS = -1.61220144e-08    RHS = 0.00000000e+00    Violation = 1.61e-08
# LHS = -1.65319810e-08    RHS = 0.00000000e+00    Violation = 1.65e-08
# LHS = -3.07065382e-08    RHS = 0.00000000e+00    Violation = 3.07e-08
# LHS = -3.05491238e-08    RHS = 0.00000000e+00    Violation = 3.05e-08
# LHS = -2.99520078e-08    RHS = 0.00000000e+00    Violation = 3.00e-08
# LHS = -2.86948574e-08    RHS = 0.00000000e+00    Violation = 2.87e-08
# LHS = -2.72872835e-08    RHS = 0.00000000e+00    Violation = 2.73e-08
# LHS = -2.52370860e-08    RHS = 0.00000000e+00    Violation = 2.52e-08
# LHS = -2.24146411e-08    RHS = 0.00000000e+00    Violation = 2.24e-08
# LHS = -2.22268747e-08    RHS = 0.00000000e+00    Violation = 2.22e-08
# LHS = -2.12901909e-08    RHS = 0.00000000e+00    Violation = 2.13e-08
# LHS = -1.68163996e-08    RHS = 0.00000000e+00    Violation = 1.68e-08
# LHS = -1.70498307e-08    RHS = 0.00000000e+00    Violation = 1.70e-08
# LHS = -5.07038533e-09    RHS = 0.00000000e+00    Violation = 5.07e-09
# LHS = -1.07010813e-08    RHS = 0.00000000e+00    Violation = 1.07e-08
# LHS = -2.44766734e-08    RHS = 0.00000000e+00    Violation = 2.45e-08
# LHS = -3.25335020e-08    RHS = 0.00000000e+00    Violation = 3.25e-08
# LHS = -3.79890375e-08    RHS = 0.00000000e+00    Violation = 3.80e-08
# LHS = -1.47894183e-08    RHS = 0.00000000e+00    Violation = 1.48e-08
# LHS = -3.22015106e-08    RHS = 0.00000000e+00    Violation = 3.22e-08
# LHS = -1.56227021e-08    RHS = 0.00000000e+00    Violation = 1.56e-08
# LHS = -2.83960634e-08    RHS = 0.00000000e+00    Violation = 2.84e-08
# LHS = -3.37396905e-08    RHS = 0.00000000e+00    Violation = 3.37e-08
# LHS = -3.67729547e-08    RHS = 0.00000000e+00    Violation = 3.68e-08
# LHS = -3.31896963e-08    RHS = 0.00000000e+00    Violation = 3.32e-08
# LHS = -2.74431207e-08    RHS = 0.00000000e+00    Violation = 2.74e-08
# LHS = -1.30617259e-08    RHS = 0.00000000e+00    Violation = 1.31e-08
# LHS = -1.23752562e-08    RHS = 0.00000000e+00    Violation = 1.24e-08
# LHS = -4.88252519e-08    RHS = 0.00000000e+00    Violation = 4.88e-08
# LHS = -3.68846395e-08    RHS = 0.00000000e+00    Violation = 3.69e-08
# LHS = -1.56367642e-07    RHS = 0.00000000e+00    Violation = 1.56e-07
# LHS = -3.92841068e-08    RHS = 0.00000000e+00    Violation = 3.93e-08
# LHS = -5.11435268e-08    RHS = 0.00000000e+00    Violation = 5.11e-08
# LHS = -4.88988604e-08    RHS = 0.00000000e+00    Violation = 4.89e-08
# LHS = -1.55942675e-08    RHS = 0.00000000e+00    Violation = 1.56e-08
# LHS = -2.51114065e-08    RHS = 0.00000000e+00    Violation = 2.51e-08
# LHS = -1.91531590e-08    RHS = 0.00000000e+00    Violation = 1.92e-08
# LHS = -1.93491512e-08    RHS = 0.00000000e+00    Violation = 1.93e-08
# LHS = -2.23992507e-08    RHS = 0.00000000e+00    Violation = 2.24e-08
# LHS = -1.84020648e-08    RHS = 0.00000000e+00    Violation = 1.84e-08
# LHS = -1.10030163e-08    RHS = 0.00000000e+00    Violation = 1.10e-08
# LHS = -1.79991027e-08    RHS = 0.00000000e+00    Violation = 1.80e-08
# LHS = -1.81432980e-08    RHS = 0.00000000e+00    Violation = 1.81e-08
# LHS = -1.80647660e-08    RHS = 0.00000000e+00    Violation = 1.81e-08
# LHS = -1.81549399e-08    RHS = 0.00000000e+00    Violation = 1.82e-08
# LHS = -1.84604271e-08    RHS = 0.00000000e+00    Violation = 1.85e-08
# LHS = -1.88998153e-08    RHS = 0.00000000e+00    Violation = 1.89e-08
# LHS = -1.29506210e-08    RHS = 0.00000000e+00    Violation = 1.30e-08
# LHS = -1.31053474e-08    RHS = 0.00000000e+00    Violation = 1.31e-08
# LHS = -1.31882273e-08    RHS = 0.00000000e+00    Violation = 1.32e-08
# LHS = -1.33739442e-08    RHS = 0.00000000e+00    Violation = 1.34e-08
# LHS = -1.34544227e-08    RHS = 0.00000000e+00    Violation = 1.35e-08
# LHS = -1.31240752e-08    RHS = 0.00000000e+00    Violation = 1.31e-08
# LHS = -1.27999556e-08    RHS = 0.00000000e+00    Violation = 1.28e-08
# LHS = -1.25882610e-08    RHS = 0.00000000e+00    Violation = 1.26e-08
# LHS = -1.24355552e-08    RHS = 0.00000000e+00    Violation = 1.24e-08
# LHS = -1.24664849e-08    RHS = 0.00000000e+00    Violation = 1.25e-08
# LHS = -1.24790564e-08    RHS = 0.00000000e+00    Violation = 1.25e-08
# LHS = -1.48448083e-08    RHS = 0.00000000e+00    Violation = 1.48e-08
# LHS = -1.87680851e-08    RHS = 0.00000000e+00    Violation = 1.88e-08
# LHS = -4.60520292e-08    RHS = 0.00000000e+00    Violation = 4.61e-08
# LHS = -9.57737371e-08    RHS = 0.00000000e+00    Violation = 9.58e-08
# LHS = -1.85236155e-07    RHS = 0.00000000e+00    Violation = 1.85e-07
# LHS = -1.66890225e-08    RHS = 0.00000000e+00    Violation = 1.67e-08
# LHS = -2.48438806e-08    RHS = 0.00000000e+00    Violation = 2.48e-08
# LHS = -2.26831365e-08    RHS = 0.00000000e+00    Violation = 2.27e-08
# LHS = -2.85987804e-08    RHS = 0.00000000e+00    Violation = 2.86e-08
# LHS = -2.29459094e-08    RHS = 0.00000000e+00    Violation = 2.29e-08
# LHS = -2.71077929e-08    RHS = 0.00000000e+00    Violation = 2.71e-08
# LHS = -4.45090923e-08    RHS = 0.00000000e+00    Violation = 4.45e-08
# LHS = -4.46732371e-08    RHS = 0.00000000e+00    Violation = 4.47e-08
# LHS = -4.46641262e-08    RHS = 0.00000000e+00    Violation = 4.47e-08
# LHS = -4.48428209e-08    RHS = 0.00000000e+00    Violation = 4.48e-08
# LHS = -4.40222884e-08    RHS = 0.00000000e+00    Violation = 4.40e-08
# LHS = -2.82783468e-08    RHS = 0.00000000e+00    Violation = 2.83e-08
# LHS = -3.76536546e-08    RHS = 0.00000000e+00    Violation = 3.77e-08
# LHS = -1.91574478e-08    RHS = 0.00000000e+00    Violation = 1.92e-08
# LHS = -2.23508106e-08    RHS = 0.00000000e+00    Violation = 2.24e-08
# LHS = -1.65186877e-08    RHS = 0.00000000e+00    Violation = 1.65e-08
# LHS = -1.52094202e-07    RHS = 0.00000000e+00    Violation = 1.52e-07
# LHS = -1.19364667e-07    RHS = 0.00000000e+00    Violation = 1.19e-07
# LHS = -9.27951099e-08    RHS = 0.00000000e+00    Violation = 9.28e-08
# LHS = -1.79596135e-08    RHS = 0.00000000e+00    Violation = 1.80e-08
# LHS = -4.35884002e-09    RHS = 0.00000000e+00    Violation = 4.36e-09
# LHS = -1.84247496e-08    RHS = 0.00000000e+00    Violation = 1.84e-08
# LHS = -1.84944711e-08    RHS = 0.00000000e+00    Violation = 1.85e-08
# LHS = -1.09778328e-08    RHS = 0.00000000e+00    Violation = 1.10e-08
# LHS = -1.83333381e-08    RHS = 0.00000000e+00    Violation = 1.83e-08
# LHS = -2.63898314e-08    RHS = 0.00000000e+00    Violation = 2.64e-08
# LHS = -1.76001944e-08    RHS = 0.00000000e+00    Violation = 1.76e-08
# LHS = -1.42172137e-08    RHS = 0.00000000e+00    Violation = 1.42e-08
# LHS = -1.61678929e-08    RHS = 0.00000000e+00    Violation = 1.62e-08
# LHS = -1.39135982e-08    RHS = 0.00000000e+00    Violation = 1.39e-08
# LHS = -1.04330653e-08    RHS = 0.00000000e+00    Violation = 1.04e-08
# LHS = -1.02395488e-08    RHS = 0.00000000e+00    Violation = 1.02e-08
# LHS = -1.02490681e-08    RHS = 0.00000000e+00    Violation = 1.02e-08
# LHS = -1.01561772e-08    RHS = 0.00000000e+00    Violation = 1.02e-08
# LHS = -1.04385204e-08    RHS = 0.00000000e+00    Violation = 1.04e-08
# LHS = -1.37397277e-08    RHS = 0.00000000e+00    Violation = 1.37e-08
# LHS = -1.34974392e-08    RHS = 0.00000000e+00    Violation = 1.35e-08
# LHS = -1.31535298e-08    RHS = 0.00000000e+00    Violation = 1.32e-08
# LHS = -1.28241938e-08    RHS = 0.00000000e+00    Violation = 1.28e-08
# LHS = -1.26157985e-08    RHS = 0.00000000e+00    Violation = 1.26e-08
# LHS = -1.24665916e-08    RHS = 0.00000000e+00    Violation = 1.25e-08
# LHS = -1.25224621e-08    RHS = 0.00000000e+00    Violation = 1.25e-08
# LHS = -1.25423602e-08    RHS = 0.00000000e+00    Violation = 1.25e-08
# LHS = -1.49556038e-08    RHS = 0.00000000e+00    Violation = 1.50e-08
# LHS = -1.90003286e-08    RHS = 0.00000000e+00    Violation = 1.90e-08
# LHS = -4.60520292e-08    RHS = 0.00000000e+00    Violation = 4.61e-08
# LHS = -9.57737371e-08    RHS = 0.00000000e+00    Violation = 9.58e-08
# LHS = -1.85236155e-07    RHS = 0.00000000e+00    Violation = 1.85e-07
# LHS = -1.66890225e-08    RHS = 0.00000000e+00    Violation = 1.67e-08
# LHS = -2.48438806e-08    RHS = 0.00000000e+00    Violation = 2.48e-08
# LHS = -2.26831365e-08    RHS = 0.00000000e+00    Violation = 2.27e-08
# LHS = -2.85987804e-08    RHS = 0.00000000e+00    Violation = 2.86e-08
# LHS = -2.29459094e-08    RHS = 0.00000000e+00    Violation = 2.29e-08
# LHS = -2.71077929e-08    RHS = 0.00000000e+00    Violation = 2.71e-08
# LHS = -4.45090923e-08    RHS = 0.00000000e+00    Violation = 4.45e-08
# LHS = -4.46732371e-08    RHS = 0.00000000e+00    Violation = 4.47e-08
# LHS = -4.46641262e-08    RHS = 0.00000000e+00    Violation = 4.47e-08
# LHS = -4.48428209e-08    RHS = 0.00000000e+00    Violation = 4.48e-08
# LHS = -4.40222884e-08    RHS = 0.00000000e+00    Violation = 4.40e-08
# LHS = -2.82783468e-08    RHS = 0.00000000e+00    Violation = 2.83e-08
# LHS = -3.76536546e-08    RHS = 0.00000000e+00    Violation = 3.77e-08
# LHS = -1.91574478e-08    RHS = 0.00000000e+00    Violation = 1.92e-08
# LHS = -2.23508106e-08    RHS = 0.00000000e+00    Violation = 2.24e-08
# LHS = -1.97894265e-08    RHS = 0.00000000e+00    Violation = 1.98e-08
# LHS = -1.14217284e-07    RHS = 0.00000000e+00    Violation = 1.14e-07
# LHS = -9.08826760e-08    RHS = 0.00000000e+00    Violation = 9.09e-08
# LHS = -8.99525719e-08    RHS = 0.00000000e+00    Violation = 9.00e-08
# LHS = -1.74473190e-08    RHS = 0.00000000e+00    Violation = 1.74e-08
# LHS = -1.19450230e-08    RHS = 0.00000000e+00    Violation = 1.19e-08
# LHS = -1.29360629e-08    RHS = 0.00000000e+00    Violation = 1.29e-08
# LHS = -1.27967159e-08    RHS = 0.00000000e+00    Violation = 1.28e-08
# LHS = -1.36426384e-08    RHS = 0.00000000e+00    Violation = 1.36e-08
# LHS = -1.29250395e-08    RHS = 0.00000000e+00    Violation = 1.29e-08
# LHS = -3.55536277e-08    RHS = 0.00000000e+00    Violation = 3.56e-08
# LHS = -1.14870939e-08    RHS = 0.00000000e+00    Violation = 1.15e-08
# LHS = -1.15608453e-08    RHS = 0.00000000e+00    Violation = 1.16e-08
# LHS = -1.15249724e-08    RHS = 0.00000000e+00    Violation = 1.15e-08
# LHS = -1.15614030e-08    RHS = 0.00000000e+00    Violation = 1.16e-08
# LHS = -1.17445244e-08    RHS = 0.00000000e+00    Violation = 1.17e-08
# LHS = -1.19798493e-08    RHS = 0.00000000e+00    Violation = 1.20e-08
# (0, 1, 0)
# LHS = -8.08249655e-04    RHS = 0.00000000e+00    Violation = 8.08e-04
# (0, 1, 1)
# LHS = -8.35624530e-04    RHS = 0.00000000e+00    Violation = 8.36e-04
# (0, 1, 2)
# LHS = -8.51431517e-04    RHS = 0.00000000e+00    Violation = 8.51e-04
# (0, 1, 3)
# LHS = -2.39380797e-03    RHS = 0.00000000e+00    Violation = 2.39e-03
# (0, 1, 4)
# LHS = -1.08626388e-03    RHS = 0.00000000e+00    Violation = 1.09e-03
# (0, 1, 5)
# LHS = -1.19146636e-03    RHS = 0.00000000e+00    Violation = 1.19e-03
# (0, 1, 6)
# LHS = -1.32134628e-03    RHS = 0.00000000e+00    Violation = 1.32e-03
# (0, 1, 7)
# LHS = -1.44094626e-03    RHS = 0.00000000e+00    Violation = 1.44e-03
# (0, 1, 8)
# LHS = -1.60593568e-03    RHS = 0.00000000e+00    Violation = 1.61e-03
# (0, 1, 9)
# LHS = -1.85585971e-03    RHS = 0.00000000e+00    Violation = 1.86e-03
# (0, 1, 10)
# LHS = -1.87423620e-03    RHS = 0.00000000e+00    Violation = 1.87e-03
# (0, 1, 11)
# LHS = -1.82081538e-03    RHS = 0.00000000e+00    Violation = 1.82e-03
# (0, 1, 12)
# LHS = -2.52981978e-03    RHS = 0.00000000e+00    Violation = 2.53e-03
# (0, 1, 13)
# LHS = -9.06390033e-03    RHS = 0.00000000e+00    Violation = 9.06e-03
# (0, 1, 14)
# LHS = -3.45875950e-02    RHS = 0.00000000e+00    Violation = 3.46e-02
# (0, 1, 15)
# LHS = -5.04793481e-02    RHS = 0.00000000e+00    Violation = 5.05e-02
# (0, 1, 16)
# LHS = -1.84421530e-03    RHS = 0.00000000e+00    Violation = 1.84e-03
# (0, 1, 17)
# LHS = -8.59079420e-04    RHS = 0.00000000e+00    Violation = 8.59e-04
# (0, 1, 18)
# LHS = -8.31528519e-04    RHS = 0.00000000e+00    Violation = 8.32e-04
# (0, 1, 19)
# LHS = -9.47760637e-04    RHS = 0.00000000e+00    Violation = 9.48e-04
# (0, 1, 20)
# LHS = -8.67450636e-04    RHS = 0.00000000e+00    Violation = 8.67e-04
# (0, 1, 21)
# LHS = -9.32058999e-04    RHS = 0.00000000e+00    Violation = 9.32e-04
# (0, 1, 22)
# LHS = -8.26962806e-02    RHS = 0.00000000e+00    Violation = 8.27e-02
# (0, 1, 23)
# LHS = -2.21129882e-01    RHS = 0.00000000e+00    Violation = 2.21e-01
# (0, 1, 24)
# LHS = -2.78814963e-01    RHS = 0.00000000e+00    Violation = 2.79e-01
# (0, 1, 25)
# LHS = -1.32350502e-01    RHS = 0.00000000e+00    Violation = 1.32e-01
# (0, 1, 26)
# LHS = -1.24017973e-03    RHS = 0.00000000e+00    Violation = 1.24e-03
# (0, 1, 27)
# LHS = -9.39108857e-04    RHS = 0.00000000e+00    Violation = 9.39e-04
# (0, 1, 28)
# LHS = -1.03612656e-03    RHS = 0.00000000e+00    Violation = 1.04e-03
# (0, 1, 29)
# LHS = -8.65157519e-04    RHS = 0.00000000e+00    Violation = 8.65e-04
# (0, 1, 30)
# LHS = -8.45454879e-04    RHS = 0.00000000e+00    Violation = 8.45e-04
# (0, 1, 31)
# LHS = -1.11105685e-02    RHS = 0.00000000e+00    Violation = 1.11e-02
# (0, 1, 32)
# LHS = -1.02972119e-02    RHS = 0.00000000e+00    Violation = 1.03e-02
# (0, 1, 33)
# LHS = -1.11721592e-02    RHS = 0.00000000e+00    Violation = 1.12e-02
# (0, 1, 34)
# LHS = -2.23398938e-02    RHS = 0.00000000e+00    Violation = 2.23e-02
# (0, 1, 35)
# LHS = -3.34490504e-03    RHS = 0.00000000e+00    Violation = 3.34e-03
# (0, 1, 36)
# LHS = -2.00866588e-03    RHS = 0.00000000e+00    Violation = 2.01e-03
# (0, 1, 37)
# LHS = -2.42167062e-03    RHS = 0.00000000e+00    Violation = 2.42e-03
# (0, 1, 38)
# LHS = -2.37618192e-03    RHS = 0.00000000e+00    Violation = 2.38e-03
# (0, 1, 39)
# LHS = -9.95712326e-04    RHS = 0.00000000e+00    Violation = 9.96e-04
# (0, 1, 40)
# LHS = -2.26827210e-03    RHS = 0.00000000e+00    Violation = 2.27e-03
# (0, 1, 41)
# LHS = -3.32885299e-03    RHS = 0.00000000e+00    Violation = 3.33e-03
# (0, 1, 42)
# LHS = -2.18743310e-03    RHS = 0.00000000e+00    Violation = 2.19e-03
# (0, 1, 43)
# LHS = -2.17587679e-03    RHS = 0.00000000e+00    Violation = 2.18e-03
# (0, 1, 44)
# LHS = -2.19387136e-03    RHS = 0.00000000e+00    Violation = 2.19e-03
# (0, 1, 45)
# LHS = -2.17124304e-03    RHS = 0.00000000e+00    Violation = 2.17e-03
# (0, 1, 46)
# LHS = -1.99848208e-03    RHS = 0.00000000e+00    Violation = 2.00e-03
# (0, 1, 47)
# LHS = -1.75730209e-03    RHS = 0.00000000e+00    Violation = 1.76e-03
# (0, 1, 48)
# LHS = -1.75190509e-03    RHS = 0.00000000e+00    Violation = 1.75e-03
# (0, 1, 49)
# LHS = -1.90062599e-03    RHS = 0.00000000e+00    Violation = 1.90e-03
# (0, 1, 50)
# LHS = -1.99921103e-03    RHS = 0.00000000e+00    Violation = 2.00e-03
# (0, 1, 51)
# LHS = -1.02793811e-03    RHS = 0.00000000e+00    Violation = 1.03e-03
# (0, 1, 52)
# LHS = -1.09148665e-03    RHS = 0.00000000e+00    Violation = 1.09e-03
# (0, 1, 53)
# LHS = -1.19916492e-03    RHS = 0.00000000e+00    Violation = 1.20e-03
# (0, 1, 54)
# LHS = -1.33245251e-03    RHS = 0.00000000e+00    Violation = 1.33e-03
# (0, 1, 55)
# LHS = -1.45530174e-03    RHS = 0.00000000e+00    Violation = 1.46e-03
# (0, 1, 56)
# LHS = -1.62493883e-03    RHS = 0.00000000e+00    Violation = 1.62e-03
# (0, 1, 57)
# LHS = -1.88211506e-03    RHS = 0.00000000e+00    Violation = 1.88e-03
# (0, 1, 58)
# LHS = -1.90094961e-03    RHS = 0.00000000e+00    Violation = 1.90e-03
# (0, 1, 59)
# LHS = -1.91033827e-03    RHS = 0.00000000e+00    Violation = 1.91e-03
# (0, 1, 60)
# LHS = -2.63641838e-03    RHS = 0.00000000e+00    Violation = 2.64e-03
# (0, 1, 61)
# LHS = -9.06390033e-03    RHS = 0.00000000e+00    Violation = 9.06e-03
# (0, 1, 62)
# LHS = -3.45875950e-02    RHS = 0.00000000e+00    Violation = 3.46e-02
# (0, 1, 63)
# LHS = -5.04793481e-02    RHS = 0.00000000e+00    Violation = 5.05e-02
# (0, 1, 64)
# LHS = -1.84421530e-03    RHS = 0.00000000e+00    Violation = 1.84e-03
# (0, 1, 65)
# LHS = -8.59079420e-04    RHS = 0.00000000e+00    Violation = 8.59e-04
# (0, 1, 66)
# LHS = -8.31528519e-04    RHS = 0.00000000e+00    Violation = 8.32e-04
# (0, 1, 67)
# LHS = -9.47760637e-04    RHS = 0.00000000e+00    Violation = 9.48e-04
# (0, 1, 68)
# LHS = -8.67450636e-04    RHS = 0.00000000e+00    Violation = 8.67e-04
# (0, 1, 69)
# LHS = -9.32058999e-04    RHS = 0.00000000e+00    Violation = 9.32e-04
# (0, 1, 70)
# LHS = -8.26962806e-02    RHS = 0.00000000e+00    Violation = 8.27e-02
# (0, 1, 71)
# LHS = -2.21129882e-01    RHS = 0.00000000e+00    Violation = 2.21e-01
# (0, 1, 72)
# LHS = -2.78814963e-01    RHS = 0.00000000e+00    Violation = 2.79e-01
# (0, 1, 73)
# LHS = -1.32350502e-01    RHS = 0.00000000e+00    Violation = 1.32e-01
# (0, 1, 74)
# LHS = -1.24017973e-03    RHS = 0.00000000e+00    Violation = 1.24e-03
# (0, 1, 75)
# LHS = -9.39108857e-04    RHS = 0.00000000e+00    Violation = 9.39e-04
# (0, 1, 76)
# LHS = -1.03612656e-03    RHS = 0.00000000e+00    Violation = 1.04e-03
# (0, 1, 77)
# LHS = -8.65157519e-04    RHS = 0.00000000e+00    Violation = 8.65e-04
# (0, 1, 78)
# LHS = -8.45454879e-04    RHS = 0.00000000e+00    Violation = 8.45e-04
# (0, 1, 79)
# LHS = -5.72210005e-02    RHS = 0.00000000e+00    Violation = 5.72e-02
# (0, 1, 80)
# LHS = -2.56615133e-02    RHS = 0.00000000e+00    Violation = 2.57e-02
# (0, 1, 81)
# LHS = -5.31998888e-02    RHS = 0.00000000e+00    Violation = 5.32e-02
# (0, 1, 82)
# LHS = -2.08514373e-02    RHS = 0.00000000e+00    Violation = 2.09e-02
# (0, 1, 83)
# LHS = -3.50070437e-03    RHS = 0.00000000e+00    Violation = 3.50e-03
# (0, 1, 84)
# LHS = -1.34300762e-03    RHS = 0.00000000e+00    Violation = 1.34e-03
# (0, 1, 85)
# LHS = -1.83257596e-03    RHS = 0.00000000e+00    Violation = 1.83e-03
# (0, 1, 86)
# LHS = -1.75166016e-03    RHS = 0.00000000e+00    Violation = 1.75e-03
# (0, 1, 87)
# LHS = -1.58731564e-03    RHS = 0.00000000e+00    Violation = 1.59e-03
# (0, 1, 88)
# LHS = -3.80721589e-03    RHS = 0.00000000e+00    Violation = 3.81e-03
# (0, 1, 89)
# LHS = -2.37294695e-02    RHS = 0.00000000e+00    Violation = 2.37e-02
# (0, 1, 90)
# LHS = -2.67192299e-03    RHS = 0.00000000e+00    Violation = 2.67e-03
# (0, 1, 91)
# LHS = -2.48985468e-03    RHS = 0.00000000e+00    Violation = 2.49e-03
# (0, 1, 92)
# LHS = -2.58581676e-03    RHS = 0.00000000e+00    Violation = 2.59e-03
# (0, 1, 93)
# LHS = -2.47479722e-03    RHS = 0.00000000e+00    Violation = 2.47e-03
# (0, 1, 94)
# LHS = -2.16410281e-03    RHS = 0.00000000e+00    Violation = 2.16e-03
# (0, 1, 95)
# LHS = -1.85327678e-03    RHS = 0.00000000e+00    Violation = 1.85e-03
